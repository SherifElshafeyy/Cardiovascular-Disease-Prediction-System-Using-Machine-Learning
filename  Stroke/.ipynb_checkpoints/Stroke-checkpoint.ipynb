# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:lightsteelblue;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;">Stroke Notebook </h1>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Data Overview</h3>

# %% [markdown]
# **According to the World Health Organization (WHO) :**
# stroke is the 2nd leading cause of death globally, responsible for approximately 11% of total deaths.
# This dataset is used to predict whether a patient is likely to get stroke based on the input parameters like gender, age, various diseases, and smoking status. Each row in the data provides relavant information about the patient.

# %% [markdown]
# |               Column               |                                            Description                                             |
# |:----------------------------------:|:--------------------------------------------------------------------------------------------------:|
# |               Gender               |                              Male or female (Nominal)                                              |
# |                Age                 |                              Age of the patient (Continuous)                                       |
# |           Hypertension             |        Whether or not the patient has hypertension (Nominal: "Yes", "No")                         |
# |           Heart Disease            |        Whether or not the patient has heart disease (Nominal: "Yes", "No")                        |
# |           Ever Married             |        Whether or not the patient has ever been married (Nominal: "Yes", "No")                    |
# |             Work Type              |        Type of occupation (Nominal: "Private", "Self-employed", "Govt_job", "children", "Never_worked") |
# |           Residence Type           |        Type of residence (Nominal: "Urban", "Rural")                                              |
# |        Avg Glucose Level          |        Average glucose level in blood (Continuous)                                                 |
# |                BMI                |                              Body Mass Index (Continuous)                                          |
# |           Smoking Status           |        Smoking status (Nominal: "formerly smoked", "never smoked", "smokes", "unknown")           |
# |              Stroke                |        Whether the patient had a stroke (Binary: "1" means "Yes", "0" means "No")                 |

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Libraries & loading the data</h3>

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\ahmed-basem\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: matplotlib in c:\users\ahmed-basem\anaconda3\lib\site-packages (from missingno) (3.5.2)
# Requirement already satisfied: scipy in c:\users\ahmed-basem\anaconda3\lib\site-packages (from missingno) (1.9.3)
# Requirement already satisfied: numpy in c:\users\ahmed-basem\anaconda3\lib\site-packages (from missingno) (1.21.6)
# Requirement already satisfied: seaborn in c:\users\ahmed-basem\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from matplotlib->missingno) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\ahmed-basem\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\ahmed-basem\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ahmed-basem\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ahmed-basem\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ahmed-basem\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ahmed-basem\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ahmed-basem\anaconda3\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# %%
df = pd.read_csv("Stroke.csv")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Exploratory Data Analysis</h3>

# %%
print(f'No. of records are {df.shape[0]}')
print(f'No. of columns are {df.shape[1]}')
# Out:
# No. of records are 5110
# No. of columns are 12

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
column = list(df.columns)
categorical_features = []
discrete_features = []

for i in column:
    if len(df[i].unique()) > 6:
        discrete_features.append(i)
    else:
        categorical_features.append(i)

print('Categorical Features :',*categorical_features)
print('Continous Features :',*discrete_features)
# Out:
# Categorical Features : gender hypertension heart_disease ever_married work_type Residence_type smoking_status stroke
# Continous Features : id age avg_glucose_level bmi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
round(df.describe())
# Out:
#             id     age  hypertension  heart_disease  avg_glucose_level  \
# count   5110.0  5110.0        5110.0         5110.0             5110.0
# mean   36518.0    43.0           0.0            0.0              106.0
# std    21162.0    23.0           0.0            0.0               45.0
# min       67.0     0.0           0.0            0.0               55.0
# 25%    17741.0    25.0           0.0            0.0               77.0
# 50%    36932.0    45.0           0.0            0.0               92.0
# 75%    54682.0    61.0           0.0            0.0              114.0
# max    72940.0    82.0           1.0            1.0              272.0
#
#           bmi  stroke
# count  4909.0  5110.0
# mean     29.0     0.0
# std       8.0     0.0
# min      10.0     0.0
# 25%      24.0     0.0
# 50%      28.0     0.0
# 75%      33.0     0.0
# max      98.0     1.0

# %%
# Remove duplicates if any
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
##Deleting ID column
df = df.drop('id', axis=1)

# %%
df.drop(df[df["gender"]=="Other"].index,axis=0,inplace=True)

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Target distribution</h3>

# %%
# let us overview the distribution of the target of our data
x = pd.DataFrame(df.groupby(['stroke'])['stroke'].count())

# Plot
fig, ax = plt.subplots(figsize=(6, 6), dpi=70)
ax.barh([1], x.stroke[1], height=0.7, color='#fe346e')
plt.text(-1050, -0.08, 'Healthy', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'style': 'normal', 'color': '#3081d0'})
plt.text(5500, -0.08, '95.7%', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'color': '#3081d0'})
ax.barh([0], x.stroke[0], height=0.7, color='#3081d0')
plt.text(-930, 1, 'Stroke', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'style': 'normal', 'color': '#fe346e'})
plt.text(900, 1, '4.3%', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'color': '#fe346e'})

fig.patch.set_facecolor('white')
ax.set_facecolor('white')

plt.text(-1150, 1.77, 'Percentage of People at Risk of Stroke', {'font': 'Serif', 'size': '25', 'weight': 'bold', 'color': 'black'})
plt.text(-1150, 1.55, 'Our data distribution looks highly unbalanced,\nit is observed that 4.3% of our sample data are at risk of developing Stroke.',
         {'font': 'Serif', 'size': '12.5', 'color': 'black'})

ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.show()

# %% [markdown]
# From distribution it is clear that **only every 4 people out of 100 people have develpoed Stroke from our sampling data**. So this this appears as a highly **unbalanced data distribution**, and null accuracy score of this distribution it self is 96%, whcih imploys any dump model should randomly predictions of stroke could reach accuracy of 96%. So, while modeling and training data, **over sampling and under sampling** have to be done to obtain good and reliable results.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Dealing With Null Values</h3>

# %%
import missingno as msno

color = ['#3081d0','#3081d0','#3081d0','#3081d0','#3081d0','#3081d0','#3081d0','#3081d0','#3081d0','#3081d0','#fe346e']
fig, ax = plt.subplots(figsize = (12,4), dpi = 70)
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

msno.bar(df, sort = 'descending', 
         color = color, 
         ax = ax, fontsize =8,
         labels = 'off', filter = 'top')

ax.text(-1,1.35,'Visualization of Nullity of The Dataset',{'font': 'serif', 'size': 24,  'color':'black'},alpha = 0.9)
ax.text(-1,1.2,'Overall there are 5110 datapoints are present in \nthe given dataset. some features have null values.',{'font': 'serif', 'size': 12,  'color':'black'}, alpha = 0.7)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90, 
                   ha = 'center', **{'font': 'serif', 'size': 14,'weight':'normal','color':'#512b58'}, alpha = 1)
ax.set_yticklabels('')
ax.spines['bottom'].set_visible(True)

plt.show()

# %% [markdown]
# **How can we deal with blanks in our data?**
#
# There are many ways. One can simply drop these records, fill the blanks with the mean, the median, or even simply the record before or after the missing value.

# %%
df['bmi'].median()
# Out:
# 28.1

# %%
df.loc[df.bmi.isnull(), 'bmi'] = df['bmi'].median()

# %% [markdown]
# **All null values have been filled**

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.to_csv("updated_Stroke.csv")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Data Visualization Functions</h3>

# %% [markdown]
# There are many different types of graphs, each with its own unique properties and applications.
#
# We will use :
#
#    1- **Pie plot** : for **Categorical data**
#
#    2- **KDE plot** (kernel density estimation plot) : for **Numerical data**
#
#    3- **Box Plot** : for **definition of outliers in numerical data**
#
#    4- **Histogram** : for **distribution of numerical data**

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Catigorical data</h3>

# %%
def pie_plot(df, group_feature, overall_title, colors):
    # Calculate percentage of each category in the group feature
    grouped = df[group_feature].value_counts(normalize=True).rename('percentage').mul(100).reset_index()

    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(figsize=(8, 6))

        wedges, texts, autotexts = ax.pie(grouped['percentage'], labels=grouped['index'],
                                           autopct='%1.1f%%', colors=colors)
        ax.set_title(f'Distribution of {overall_title}')  # Set the title to be the group feature
        plt.setp(autotexts, size=16, color="w")

        plt.tight_layout()
        plt.show()

# %%
def pie_with_target(df, group_feature, overall_title):
    # Calculate percentage of people who developed Stroke for each group
    grouped = df.groupby(group_feature)['stroke'].value_counts(normalize=True).rename('percentage').mul(100).reset_index()

    # Define custom color palette
    custom_palette = {0: '#3081d0', 1: '#fe346e'}
    # Define custom legend labels
    legend_labels = {0: 'Healthy', 1: 'Stroke'}

    unique_groups = grouped[group_feature].unique()
    num_unique_groups = len(unique_groups)

    # Ensure all Stroke statuses are in custom_palette and legend_labels
    assert set(grouped['stroke'].unique()).issubset(custom_palette.keys()), "All stroke statuses must be keys in custom_palette"
    assert set(grouped['stroke'].unique()).issubset(legend_labels.keys()), "All stroke statuses must be keys in legend_labels"

    with plt.style.context('fivethirtyeight'):
        fig, axs = plt.subplots(1, num_unique_groups, figsize=(15, 6))

        if num_unique_groups == 1:
            axs = [axs]  # To handle the case where there is only 1 group

        for i, group_status in enumerate(unique_groups):
            data = grouped[grouped[group_feature]== group_status ]
            labels = data['stroke'].map(legend_labels).tolist() # map stroke status to labels
            colors = data['stroke'].map(custom_palette).tolist() # map stroke status to colors
            wedges, texts, autotexts = axs[i].pie(data['percentage'], labels=labels, colors=colors, autopct='%1.1f%%')

            axs[i].set_title(f'{group_status}')  # Set the title to be the group feature and status
            plt.setp(autotexts, size=16, color="w")
        
        
        fig.suptitle(f'Percentage of people who developed Stroke grouped by {overall_title} status', fontsize=18)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Continuous data</h3>

# %%
def plot_distribution(df, feature, plot_title):
    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(1, 2, figsize=(20, 5))

        # Histogram
        sns.histplot(x=feature,
                     data=df, 
                     ax=ax[0],
                     linewidth=0.8,
                     color='#3081d0',
                     bins=20).set_title(f"Distribution of {plot_title}")
        ax[0].set_xlabel(plot_title)

        # Box plot for the entire distribution
        sns.boxplot(x=feature,
                    data=df,
                    linewidth=1.5,
                    width=0.5,
                    color='#3081d0',
                    ax=ax[1]).set_title(f"Box Plot of {plot_title}")
        ax[1].set_xlabel(plot_title)

        plt.show()

# %%
df['stroke'] = df['stroke'].map({1: 'Stroke', 0: 'Healthy'})
def plot_stroke_vs_Healthy(feature, plot_title, df = df):
    box_plots_colors = {'Healthy': '#3081d0', 'Stroke':'#fe346e'}
    
    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(1, 2, figsize=(20, 5))

        # KDE plot for Stroke vs Healthy
        sns.kdeplot(data=df[df['stroke']=='Stroke'], x=feature, color='#fe346e', fill=True, linewidth=1.5, ec='black', alpha=0.8, zorder=3, ax=ax[0])
        sns.kdeplot(data=df[df['stroke']=='Healthy'], x=feature, color='#3081d0', fill=True, linewidth=1.5, ec='black', alpha=0.8, zorder=3, ax=ax[0])

        ax[0].set_title(f"KDE Plot of {plot_title} by Stroke")
        ax[0].set_xlabel(plot_title)
        ax[0].set_ylabel('Density')

        # Box plot for Stroke vs Healthy
        sns.boxplot(x=feature,
                    data=df,
                    y="stroke",
                    linewidth=1.5,
                    palette=box_plots_colors,
                    ax=ax[1]).set_title(f"Distribution of {plot_title} by Stroke")
        ax[1].set_xlabel(plot_title)
        ax[1].set_ylabel('Stroke')

        plt.show()

# %% [markdown]
# # <a id="2.2"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Feature Statistics Functions</h3>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Catigorical data</h3>

# %%
def explore_categorical_variable(feature, data = df):
    # Extract the column from the dataset
    column = data[feature]
    
    # Data type
    data_type = column.dtype
    
    # Count of each category
    count = column.count()
    
    # Mode (most frequent category)
    mode = column.mode().iloc[0]
    
    unique_values = column.nunique()
    
    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Data Type', 'Count', 'Mode', 'Num of Possible values'],
        'Values': [data_type, count,  mode , unique_values ]
    })
    
    # Remove the index column
    results_df = results_df.reset_index(drop=True)
    
    return results_df

# %%
def explore_categories(feature_name, category_names, data=df):
    
    # Extract the column from the dataset
    column = data[feature_name]

    # Data type
    data_type = str(column.dtype)

    # Count of each category
    category_counts = column.value_counts()

    # Percentage of each category
    category_percentages = {category: count / column.count() * 100 for category, count in category_counts.items()}

    # Create a DataFrame for count, percentage, data type, and mode
    result_df = pd.DataFrame({
        f'{feature_name}': category_counts.index,
        'Count': category_counts.values,
        'Percentage': [category_percentages.get(category, 0) for category in category_counts.index],
    })

    # Formatting for Percentage column
    result_df['Percentage'] = result_df['Percentage'].round(2)

    return result_df

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Continuous data</h3>

# %%
def explore_continuous_variable(feature, data=df):
    # Extract the column from the dataset
    column = data[feature]
    
    # Data type
    data_type = column.dtype
    
    # Basic statistics
    minimum = int(column.min())
    maximum = int(column.max())
    data_range = maximum - minimum
    mean = round(column.mean())
    median = int(column.median())
    q3 = int(column.quantile(0.75))
    q1 = int(column.quantile(0.25))
    iqr = q3 - q1
    variance = round(column.var(), 2)
    std_deviation = round(column.std(), 2)
    coefficient_of_variation = round(np.sqrt(variance) / mean, 2)
    skewness = round(column.skew(), 2)
    
    # Percentiles
    percentiles = column.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])
    
    # Number of null values
    num_null_values = column.isnull().sum()
    
    # Calculate outliers based on IQR
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers_percentage = round(((column < lower_bound) | (column > upper_bound)).mean() * 100, 2)
    
    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Feature', 'Data Type', 'Minimum Value', 'Maximum Value', 'Range', 'Mean', 'Median', 'Q3', 'Q1',
                       'IQR', 'Outliers Percentage', 'Variance', 'Standard Deviation', 'Coefficient of Variation', 'Skewness',
                       '10th Percentile', '25th Percentile', '50th Percentile', '75th Percentile', '90th Percentile',
                       'Number of Null Values','Lower Band' , 'Upper Band'],
        'Values': [feature, data_type, minimum, maximum, data_range, mean, median, q3, q1, iqr, outliers_percentage, variance, std_deviation,
                   coefficient_of_variation, skewness, int(percentiles['10%']), int(percentiles['25%']),
                   int(percentiles['50%']), int(percentiles['75%']), int(percentiles['90%']), num_null_values , lower_bound , upper_bound  
                   ]
    })
    
    results_df = results_df.reset_index(drop=True)
    
    # Create a Styler object
    styled_df = results_df.style.set_properties(**{'text-align': 'center'})
    
    return styled_df

# %%
def compare_feature_statistics(feature, data=df):
    # Extract the column for Stroke and Healthy individuals
    stroke_column = data[data['stroke'] == 1][feature]
    healthy_column = data[data['stroke'] == 0][feature]

    # Basic statistics for Stroke
    stroke_mean = int(stroke_column.mean())
    stroke_median = int(stroke_column.median())
    stroke_std_deviation = round(stroke_column.std(), 2)
    stroke_min = int(stroke_column.min())
    stroke_max = int(stroke_column.max())
    stroke_iqr = int(stroke_column.quantile(0.75) - stroke_column.quantile(0.25))

    # Basic statistics for Healthy
    healthy_mean = int(healthy_column.mean())
    healthy_median = int(healthy_column.median())
    healthy_std_deviation = round(healthy_column.std(), 2)
    healthy_min = int(healthy_column.min())
    healthy_max = int(healthy_column.max())
    healthy_iqr = int(healthy_column.quantile(0.75) - healthy_column.quantile(0.25))

    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Mean', 'Median', 'Std Deviation', 'Min', 'Max', 'IQR'],
        'Stroke': [stroke_mean, stroke_median, stroke_std_deviation, stroke_min, stroke_max, stroke_iqr],
        'Healthy': [healthy_mean, healthy_median, healthy_std_deviation, healthy_min, healthy_max, healthy_iqr]
    })

    results_df = results_df.set_index('Statistics')
    
    results_df = results_df.astype(int)

    # Create a Styler object
    styled_df = results_df.style.set_properties(**{'text-align': 'center'})

    return styled_df

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Features</h3>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Gender</h3>

# %% [markdown]
# **Male or Female**

# %%
explore_categorical_variable('gender')
# Out:
#                Statistics  Values
# 0               Data Type  object
# 1                   Count    5109
# 2                    Mode  Female
# 3  Num of Possible values       2

# %%
pie_plot(df, 'gender', 'Gender', colors=['#fe346e','#3081D0'])

# %%
explore_categories('gender',['male','female'])
# Out:
#    gender  Count  Percentage
# 0  Female   2994        58.6
# 1    Male   2115        41.4

# %%
pie_with_target(df, 'gender', 'Gender')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\4264632779.py in <module>
# ----> 1 pie_with_target(df, 'gender', 'Gender')
#
# ~\AppData\Local\Temp\ipykernel_4760\3672884752.py in pie_with_target(df, group_feature, overall_title)
#      12
#      13     # Ensure all Stroke statuses are in custom_palette and legend_labels
# ---> 14     assert set(grouped['stroke'].unique()).issubset(custom_palette.keys()), "All stroke statuses must be keys in custom_palette"
#      15     assert set(grouped['stroke'].unique()).issubset(legend_labels.keys()), "All stroke statuses must be keys in legend_labels"
#      16
#
# AssertionError: All stroke statuses must be keys in custom_palette

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Age</h3>

# %% [markdown]
# **Age of the patient**

# %%
explore_continuous_variable('age')
# Out:
# <style type="text/css">
# #T_45501_row0_col0, #T_45501_row0_col1, #T_45501_row1_col0, #T_45501_row1_col1, #T_45501_row2_col0, #T_45501_row2_col1, #T_45501_row3_col0, #T_45501_row3_col1, #T_45501_row4_col0, #T_45501_row4_col1, #T_45501_row5_col0, #T_45501_row5_col1, #T_45501_row6_col0, #T_45501_row6_col1, #T_45501_row7_col0, #T_45501_row7_col1, #T_45501_row8_col0, #T_45501_row8_col1, #T_45501_row9_col0, #T_45501_row9_col1, #T_45501_row10_col0, #T_45501_row10_col1, #T_45501_row11_col0, #T_45501_row11_col1, #T_45501_row12_col0, #T_45501_row12_col1, #T_45501_row13_col0, #T_45501_row13_col1, #T_45501_row14_col0, #T_45501_row14_col1, #T_45501_row15_col0, #T_45501_row15_col1, #T_45501_row16_col0, #T_45501_row16_col1, #T_45501_row17_col0, #T_45501_row17_col1, #T_45501_row18_col0, #T_45501_row18_col1, #T_45501_row19_col0, #T_45501_row19_col1, #T_45501_row20_col0, #T_45501_row20_col1, #T_45501_row21_col0, #T_45501_row21_col1, #T_45501_row22_col0, #T_45501_row22_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_45501">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45501_level0_col0" class="col_heading level0 col0" >Statistics</th>
#       <th id="T_45501_level0_col1" class="col_heading level0 col1" >Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45501_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45501_row0_col0" class="data row0 col0" >Feature</td>
#       <td id="T_45501_row0_col1" class="data row0 col1" >age</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45501_row1_col0" class="data row1 col0" >Data Type</td>
#       <td id="T_45501_row1_col1" class="data row1 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45501_row2_col0" class="data row2 col0" >Minimum Value</td>
#       <td id="T_45501_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45501_row3_col0" class="data row3 col0" >Maximum Value</td>
#       <td id="T_45501_row3_col1" class="data row3 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_45501_row4_col0" class="data row4 col0" >Range</td>
#       <td id="T_45501_row4_col1" class="data row4 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_45501_row5_col0" class="data row5 col0" >Mean</td>
#       <td id="T_45501_row5_col1" class="data row5 col1" >43</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_45501_row6_col0" class="data row6 col0" >Median</td>
#       <td id="T_45501_row6_col1" class="data row6 col1" >45</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_45501_row7_col0" class="data row7 col0" >Q3</td>
#       <td id="T_45501_row7_col1" class="data row7 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_45501_row8_col0" class="data row8 col0" >Q1</td>
#       <td id="T_45501_row8_col1" class="data row8 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_45501_row9_col0" class="data row9 col0" >IQR</td>
#       <td id="T_45501_row9_col1" class="data row9 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_45501_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#       <td id="T_45501_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_45501_row11_col0" class="data row11 col0" >Variance</td>
#       <td id="T_45501_row11_col1" class="data row11 col1" >511.370000</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_45501_row12_col0" class="data row12 col0" >Standard Deviation</td>
#       <td id="T_45501_row12_col1" class="data row12 col1" >22.610000</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_45501_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#       <td id="T_45501_row13_col1" class="data row13 col1" >0.530000</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_45501_row14_col0" class="data row14 col0" >Skewness</td>
#       <td id="T_45501_row14_col1" class="data row14 col1" >-0.140000</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_45501_row15_col0" class="data row15 col0" >10th Percentile</td>
#       <td id="T_45501_row15_col1" class="data row15 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_45501_row16_col0" class="data row16 col0" >25th Percentile</td>
#       <td id="T_45501_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_45501_row17_col0" class="data row17 col0" >50th Percentile</td>
#       <td id="T_45501_row17_col1" class="data row17 col1" >45</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_45501_row18_col0" class="data row18 col0" >75th Percentile</td>
#       <td id="T_45501_row18_col1" class="data row18 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_45501_row19_col0" class="data row19 col0" >90th Percentile</td>
#       <td id="T_45501_row19_col1" class="data row19 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_45501_row20_col0" class="data row20 col0" >Number of Null Values</td>
#       <td id="T_45501_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_45501_row21_col0" class="data row21 col0" >Lower Band</td>
#       <td id="T_45501_row21_col1" class="data row21 col1" >-29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_45501_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_45501_row22_col0" class="data row22 col0" >Upper Band</td>
#       <td id="T_45501_row22_col1" class="data row22 col1" >115.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_distribution(df, 'age', 'Age')

# %%
compare_feature_statistics('age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\2261690180.py in <module>
# ----> 1 compare_feature_statistics('age')
#
# ~\AppData\Local\Temp\ipykernel_4760\969570161.py in compare_feature_statistics(feature, data)
#       5
#       6     # Basic statistics for Stroke
# ----> 7     stroke_mean = int(stroke_column.mean())
#       8     stroke_median = int(stroke_column.median())
#       9     stroke_std_deviation = round(stroke_column.std(), 2)
#
# ValueError: cannot convert float NaN to integer

# %%
plot_stroke_vs_Healthy("age", "Age")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Hypertension</h3>

# %% [markdown]
# **Whether or not the patient has hypertension**

# %%
explore_categorical_variable('hypertension')

# %%
pie_plot(df, 'hypertension', 'Hypertension', colors=['#fe346e','#3081D0'])

# %%
explore_categories('hypertension',[0.1])
# Out:
#    hypertension  Count  Percentage
# 0             0   4611       90.25
# 1             1    498        9.75

# %%
pie_with_target(df, 'hypertension', 'Hypertension')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\1942170594.py in <module>
# ----> 1 pie_with_target(df, 'hypertension', 'Hypertension')
#
# ~\AppData\Local\Temp\ipykernel_4760\3672884752.py in pie_with_target(df, group_feature, overall_title)
#      12
#      13     # Ensure all Stroke statuses are in custom_palette and legend_labels
# ---> 14     assert set(grouped['stroke'].unique()).issubset(custom_palette.keys()), "All stroke statuses must be keys in custom_palette"
#      15     assert set(grouped['stroke'].unique()).issubset(legend_labels.keys()), "All stroke statuses must be keys in legend_labels"
#      16
#
# AssertionError: All stroke statuses must be keys in custom_palette

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Heart disease</h3>

# %% [markdown]
# **Whether or not the patient has heart disease**

# %%
explore_categorical_variable('heart_disease')
# Out:
#                Statistics Values
# 0               Data Type  int64
# 1                   Count   5109
# 2                    Mode      0
# 3  Num of Possible values      2

# %%
pie_plot(df, 'heart_disease', 'Heart disease', colors=['#fe346e','#3081D0'])

# %%
explore_categories('heart_disease',[0.1])
# Out:
#    heart_disease  Count  Percentage
# 0              0   4833        94.6
# 1              1    276         5.4

# %%
# pie_with_target(df, 'heart_disease', 'Heart disease')

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Ever married</h3>

# %% [markdown]
# **Whether or not the patient has ever been married**

# %%
explore_categorical_variable('ever_married')
# Out:
#                Statistics  Values
# 0               Data Type  object
# 1                   Count    5109
# 2                    Mode     Yes
# 3  Num of Possible values       2

# %%
pie_plot(df, 'ever_married', 'Ever married', colors=['#fe346e','#3081D0'])

# %%
explore_categories('ever_married',['Yes','No'])
# Out:
#   ever_married  Count  Percentage
# 0          Yes   3353       65.63
# 1           No   1756       34.37

# %%
pie_with_target(df, 'ever_married', 'Ever married')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\1148886089.py in <module>
# ----> 1 pie_with_target(df, 'ever_married', 'Ever married')
#
# ~\AppData\Local\Temp\ipykernel_4760\3672884752.py in pie_with_target(df, group_feature, overall_title)
#      12
#      13     # Ensure all Stroke statuses are in custom_palette and legend_labels
# ---> 14     assert set(grouped['stroke'].unique()).issubset(custom_palette.keys()), "All stroke statuses must be keys in custom_palette"
#      15     assert set(grouped['stroke'].unique()).issubset(legend_labels.keys()), "All stroke statuses must be keys in legend_labels"
#      16
#
# AssertionError: All stroke statuses must be keys in custom_palette

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Work type</h3>

# %% [markdown]
# **Type of occupation**

# %%
explore_categorical_variable('work_type')
# Out:
#                Statistics   Values
# 0               Data Type   object
# 1                   Count     5109
# 2                    Mode  Private
# 3  Num of Possible values        5

# %%
pie_plot(df, 'work_type', 'Work type', colors=['#3081d0','#fe346e','#1c4966','#fc94ad','#add8e6'])

# %%
explore_categories('work_type',['Private' , 'Never_worked' , 'Govt_job' , 'children' , 'Self-employed'])
# Out:
#        work_type  Count  Percentage
# 0        Private   2924       57.23
# 1  Self-employed    819       16.03
# 2       children    687       13.45
# 3       Govt_job    657       12.86
# 4   Never_worked     22        0.43

# %%
pie_with_target(df,'work_type', 'Work type')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\1661761644.py in <module>
# ----> 1 pie_with_target(df,'work_type', 'Work type')
#
# ~\AppData\Local\Temp\ipykernel_4760\3672884752.py in pie_with_target(df, group_feature, overall_title)
#      12
#      13     # Ensure all Stroke statuses are in custom_palette and legend_labels
# ---> 14     assert set(grouped['stroke'].unique()).issubset(custom_palette.keys()), "All stroke statuses must be keys in custom_palette"
#      15     assert set(grouped['stroke'].unique()).issubset(legend_labels.keys()), "All stroke statuses must be keys in legend_labels"
#      16
#
# AssertionError: All stroke statuses must be keys in custom_palette

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Residence type</h3>

# %% [markdown]
# **Type of residence**

# %%
explore_categorical_variable('Residence_type')
# Out:
#                Statistics  Values
# 0               Data Type  object
# 1                   Count    5109
# 2                    Mode   Urban
# 3  Num of Possible values       2

# %%
pie_plot(df, 'Residence_type', 'Residence type', colors=['#fe346e','#3081D0'])

# %%
explore_categories('Residence_type',['Rural','Urban'])
# Out:
#   Residence_type  Count  Percentage
# 0          Urban   2596       50.81
# 1          Rural   2513       49.19

# %%
pie_with_target(df, 'Residence_type', 'Residence type')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\920711220.py in <module>
# ----> 1 pie_with_target(df, 'Residence_type', 'Residence type')
#
# ~\AppData\Local\Temp\ipykernel_4760\3672884752.py in pie_with_target(df, group_feature, overall_title)
#      12
#      13     # Ensure all Stroke statuses are in custom_palette and legend_labels
# ---> 14     assert set(grouped['stroke'].unique()).issubset(custom_palette.keys()), "All stroke statuses must be keys in custom_palette"
#      15     assert set(grouped['stroke'].unique()).issubset(legend_labels.keys()), "All stroke statuses must be keys in legend_labels"
#      16
#
# AssertionError: All stroke statuses must be keys in custom_palette

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Avg glucose level</h3>

# %% [markdown]
# **Average glucose level in blood**

# %%
explore_continuous_variable('avg_glucose_level')
# Out:
# <style type="text/css">
# #T_62a28_row0_col0, #T_62a28_row0_col1, #T_62a28_row1_col0, #T_62a28_row1_col1, #T_62a28_row2_col0, #T_62a28_row2_col1, #T_62a28_row3_col0, #T_62a28_row3_col1, #T_62a28_row4_col0, #T_62a28_row4_col1, #T_62a28_row5_col0, #T_62a28_row5_col1, #T_62a28_row6_col0, #T_62a28_row6_col1, #T_62a28_row7_col0, #T_62a28_row7_col1, #T_62a28_row8_col0, #T_62a28_row8_col1, #T_62a28_row9_col0, #T_62a28_row9_col1, #T_62a28_row10_col0, #T_62a28_row10_col1, #T_62a28_row11_col0, #T_62a28_row11_col1, #T_62a28_row12_col0, #T_62a28_row12_col1, #T_62a28_row13_col0, #T_62a28_row13_col1, #T_62a28_row14_col0, #T_62a28_row14_col1, #T_62a28_row15_col0, #T_62a28_row15_col1, #T_62a28_row16_col0, #T_62a28_row16_col1, #T_62a28_row17_col0, #T_62a28_row17_col1, #T_62a28_row18_col0, #T_62a28_row18_col1, #T_62a28_row19_col0, #T_62a28_row19_col1, #T_62a28_row20_col0, #T_62a28_row20_col1, #T_62a28_row21_col0, #T_62a28_row21_col1, #T_62a28_row22_col0, #T_62a28_row22_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_62a28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62a28_level0_col0" class="col_heading level0 col0" >Statistics</th>
#       <th id="T_62a28_level0_col1" class="col_heading level0 col1" >Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62a28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62a28_row0_col0" class="data row0 col0" >Feature</td>
#       <td id="T_62a28_row0_col1" class="data row0 col1" >avg_glucose_level</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_62a28_row1_col0" class="data row1 col0" >Data Type</td>
#       <td id="T_62a28_row1_col1" class="data row1 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_62a28_row2_col0" class="data row2 col0" >Minimum Value</td>
#       <td id="T_62a28_row2_col1" class="data row2 col1" >55</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_62a28_row3_col0" class="data row3 col0" >Maximum Value</td>
#       <td id="T_62a28_row3_col1" class="data row3 col1" >271</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_62a28_row4_col0" class="data row4 col0" >Range</td>
#       <td id="T_62a28_row4_col1" class="data row4 col1" >216</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_62a28_row5_col0" class="data row5 col0" >Mean</td>
#       <td id="T_62a28_row5_col1" class="data row5 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_62a28_row6_col0" class="data row6 col0" >Median</td>
#       <td id="T_62a28_row6_col1" class="data row6 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_62a28_row7_col0" class="data row7 col0" >Q3</td>
#       <td id="T_62a28_row7_col1" class="data row7 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_62a28_row8_col0" class="data row8 col0" >Q1</td>
#       <td id="T_62a28_row8_col1" class="data row8 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_62a28_row9_col0" class="data row9 col0" >IQR</td>
#       <td id="T_62a28_row9_col1" class="data row9 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_62a28_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#       <td id="T_62a28_row10_col1" class="data row10 col1" >12.230000</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_62a28_row11_col0" class="data row11 col0" >Variance</td>
#       <td id="T_62a28_row11_col1" class="data row11 col1" >2050.730000</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_62a28_row12_col0" class="data row12 col0" >Standard Deviation</td>
#       <td id="T_62a28_row12_col1" class="data row12 col1" >45.290000</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_62a28_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#       <td id="T_62a28_row13_col1" class="data row13 col1" >0.430000</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_62a28_row14_col0" class="data row14 col0" >Skewness</td>
#       <td id="T_62a28_row14_col1" class="data row14 col1" >1.570000</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_62a28_row15_col0" class="data row15 col0" >10th Percentile</td>
#       <td id="T_62a28_row15_col1" class="data row15 col1" >65</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_62a28_row16_col0" class="data row16 col0" >25th Percentile</td>
#       <td id="T_62a28_row16_col1" class="data row16 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_62a28_row17_col0" class="data row17 col0" >50th Percentile</td>
#       <td id="T_62a28_row17_col1" class="data row17 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_62a28_row18_col0" class="data row18 col0" >75th Percentile</td>
#       <td id="T_62a28_row18_col1" class="data row18 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_62a28_row19_col0" class="data row19 col0" >90th Percentile</td>
#       <td id="T_62a28_row19_col1" class="data row19 col1" >192</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_62a28_row20_col0" class="data row20 col0" >Number of Null Values</td>
#       <td id="T_62a28_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_62a28_row21_col0" class="data row21 col0" >Lower Band</td>
#       <td id="T_62a28_row21_col1" class="data row21 col1" >21.500000</td>
#     </tr>
#     <tr>
#       <th id="T_62a28_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_62a28_row22_col0" class="data row22 col0" >Upper Band</td>
#       <td id="T_62a28_row22_col1" class="data row22 col1" >169.500000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_distribution(df, 'avg_glucose_level', 'Avg glucose level')

# %%
compare_feature_statistics('avg_glucose_level')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\1322500754.py in <module>
# ----> 1 compare_feature_statistics('avg_glucose_level')
#
# ~\AppData\Local\Temp\ipykernel_4760\969570161.py in compare_feature_statistics(feature, data)
#       5
#       6     # Basic statistics for Stroke
# ----> 7     stroke_mean = int(stroke_column.mean())
#       8     stroke_median = int(stroke_column.median())
#       9     stroke_std_deviation = round(stroke_column.std(), 2)
#
# ValueError: cannot convert float NaN to integer

# %%
plot_stroke_vs_Healthy("avg_glucose_level", "Avg glucose level")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">BMI</h3>

# %% [markdown]
# **Body Mass Index**

# %%
explore_continuous_variable('bmi')
# Out:
# <style type="text/css">
# #T_5f780_row0_col0, #T_5f780_row0_col1, #T_5f780_row1_col0, #T_5f780_row1_col1, #T_5f780_row2_col0, #T_5f780_row2_col1, #T_5f780_row3_col0, #T_5f780_row3_col1, #T_5f780_row4_col0, #T_5f780_row4_col1, #T_5f780_row5_col0, #T_5f780_row5_col1, #T_5f780_row6_col0, #T_5f780_row6_col1, #T_5f780_row7_col0, #T_5f780_row7_col1, #T_5f780_row8_col0, #T_5f780_row8_col1, #T_5f780_row9_col0, #T_5f780_row9_col1, #T_5f780_row10_col0, #T_5f780_row10_col1, #T_5f780_row11_col0, #T_5f780_row11_col1, #T_5f780_row12_col0, #T_5f780_row12_col1, #T_5f780_row13_col0, #T_5f780_row13_col1, #T_5f780_row14_col0, #T_5f780_row14_col1, #T_5f780_row15_col0, #T_5f780_row15_col1, #T_5f780_row16_col0, #T_5f780_row16_col1, #T_5f780_row17_col0, #T_5f780_row17_col1, #T_5f780_row18_col0, #T_5f780_row18_col1, #T_5f780_row19_col0, #T_5f780_row19_col1, #T_5f780_row20_col0, #T_5f780_row20_col1, #T_5f780_row21_col0, #T_5f780_row21_col1, #T_5f780_row22_col0, #T_5f780_row22_col1 {
#   text-align: center;
# }
# </style>
# <table id="T_5f780">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f780_level0_col0" class="col_heading level0 col0" >Statistics</th>
#       <th id="T_5f780_level0_col1" class="col_heading level0 col1" >Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f780_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f780_row0_col0" class="data row0 col0" >Feature</td>
#       <td id="T_5f780_row0_col1" class="data row0 col1" >bmi</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f780_row1_col0" class="data row1 col0" >Data Type</td>
#       <td id="T_5f780_row1_col1" class="data row1 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f780_row2_col0" class="data row2 col0" >Minimum Value</td>
#       <td id="T_5f780_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f780_row3_col0" class="data row3 col0" >Maximum Value</td>
#       <td id="T_5f780_row3_col1" class="data row3 col1" >97</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f780_row4_col0" class="data row4 col0" >Range</td>
#       <td id="T_5f780_row4_col1" class="data row4 col1" >87</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5f780_row5_col0" class="data row5 col0" >Mean</td>
#       <td id="T_5f780_row5_col1" class="data row5 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5f780_row6_col0" class="data row6 col0" >Median</td>
#       <td id="T_5f780_row6_col1" class="data row6 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5f780_row7_col0" class="data row7 col0" >Q3</td>
#       <td id="T_5f780_row7_col1" class="data row7 col1" >32</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5f780_row8_col0" class="data row8 col0" >Q1</td>
#       <td id="T_5f780_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5f780_row9_col0" class="data row9 col0" >IQR</td>
#       <td id="T_5f780_row9_col1" class="data row9 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5f780_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#       <td id="T_5f780_row10_col1" class="data row10 col1" >2.700000</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5f780_row11_col0" class="data row11 col0" >Variance</td>
#       <td id="T_5f780_row11_col1" class="data row11 col1" >59.290000</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5f780_row12_col0" class="data row12 col0" >Standard Deviation</td>
#       <td id="T_5f780_row12_col1" class="data row12 col1" >7.700000</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5f780_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#       <td id="T_5f780_row13_col1" class="data row13 col1" >0.270000</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5f780_row14_col0" class="data row14 col0" >Skewness</td>
#       <td id="T_5f780_row14_col1" class="data row14 col1" >1.090000</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5f780_row15_col0" class="data row15 col0" >10th Percentile</td>
#       <td id="T_5f780_row15_col1" class="data row15 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5f780_row16_col0" class="data row16 col0" >25th Percentile</td>
#       <td id="T_5f780_row16_col1" class="data row16 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5f780_row17_col0" class="data row17 col0" >50th Percentile</td>
#       <td id="T_5f780_row17_col1" class="data row17 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5f780_row18_col0" class="data row18 col0" >75th Percentile</td>
#       <td id="T_5f780_row18_col1" class="data row18 col1" >32</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5f780_row19_col0" class="data row19 col0" >90th Percentile</td>
#       <td id="T_5f780_row19_col1" class="data row19 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5f780_row20_col0" class="data row20 col0" >Number of Null Values</td>
#       <td id="T_5f780_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5f780_row21_col0" class="data row21 col0" >Lower Band</td>
#       <td id="T_5f780_row21_col1" class="data row21 col1" >9.500000</td>
#     </tr>
#     <tr>
#       <th id="T_5f780_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5f780_row22_col0" class="data row22 col0" >Upper Band</td>
#       <td id="T_5f780_row22_col1" class="data row22 col1" >45.500000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_distribution(df, 'bmi', 'BMI')

# %%
compare_feature_statistics('bmi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\2472721938.py in <module>
# ----> 1 compare_feature_statistics('bmi')
#
# ~\AppData\Local\Temp\ipykernel_4760\969570161.py in compare_feature_statistics(feature, data)
#       5
#       6     # Basic statistics for Stroke
# ----> 7     stroke_mean = int(stroke_column.mean())
#       8     stroke_median = int(stroke_column.median())
#       9     stroke_std_deviation = round(stroke_column.std(), 2)
#
# ValueError: cannot convert float NaN to integer

# %%
plot_stroke_vs_Healthy("bmi", "BMI")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Smoking status</h3>

# %% [markdown]
# **Smoking status**

# %%
explore_categorical_variable('smoking_status')
# Out:
#                Statistics        Values
# 0               Data Type        object
# 1                   Count          5109
# 2                    Mode  never smoked
# 3  Num of Possible values             4

# %%
pie_plot(df, 'smoking_status', 'Smoking status', colors=['#3081d0','#fe346e','#1c4966','#fc94ad'])

# %%
explore_categories('smoking_status',['never smoked' , 'Unknown' , 'smokes' , 'formerly smoked'])
# Out:
#     smoking_status  Count  Percentage
# 0     never smoked   1892       37.03
# 1          Unknown   1544       30.22
# 2  formerly smoked    884       17.30
# 3           smokes    789       15.44

# %%
pie_with_target(df, 'smoking_status', 'Smoking status')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\1679165443.py in <module>
# ----> 1 pie_with_target(df, 'smoking_status', 'Smoking status')
#
# ~\AppData\Local\Temp\ipykernel_4760\3672884752.py in pie_with_target(df, group_feature, overall_title)
#      12
#      13     # Ensure all Stroke statuses are in custom_palette and legend_labels
# ---> 14     assert set(grouped['stroke'].unique()).issubset(custom_palette.keys()), "All stroke statuses must be keys in custom_palette"
#      15     assert set(grouped['stroke'].unique()).issubset(legend_labels.keys()), "All stroke statuses must be keys in legend_labels"
#      16
#
# AssertionError: All stroke statuses must be keys in custom_palette

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Target</h3>

# %% [markdown]
# **Whether the patient had a stroke**

# %%
explore_categorical_variable('stroke')
# Out:
#                Statistics   Values
# 0               Data Type   object
# 1                   Count     5109
# 2                    Mode  Healthy
# 3  Num of Possible values        2

# %%
pie_plot(df, 'stroke', 'Target', colors=['#fe346e','#3081D0'])

# %%
explore_categories('stroke',[0,1])
# Out:
#     stroke  Count  Percentage
# 0  Healthy   4860       95.13
# 1   Stroke    249        4.87

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Outliers handling discussion</h3>

# %% [markdown]
# During our examination of the dataset, we observed the presence of outliers in various features, as indicated by statistical measures such as box plots and histograms we have built before. These outliers were defined as values that **exceeded the range of Q3 + 1.5 IQR (interquartile range) or were below Q1 - 1.5 IQR**. However, we subsequently engaged in discussions with domain experts in the medical field to gain a deeper understanding of these outliers.
#
# The insights provided by **medical domain experts** played a crucial role in our decision-making process. We learned that the outliers we initially identified actually represent valid and plausible data points that **can exist in the real world. These values are not errors or noise but rather reflect extreme occurrences** that can contribute to a comprehensive understanding of the factors associated with CHD.
#
# Based on these discussions and the validation of the outliers, we have made the **informed decision to retain them in our analysis**.
#
# By doing so, we aim to **capture the full range of real-world scenarios and avoid introducing bias into our findings**.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Models Development</h3>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Importing Libraries</h3>

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
import joblib
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Data Scaling</h3>

# %%
df['stroke'].value_counts() / len(df)
# Out:
# Healthy    0.951262
# Stroke     0.048738
# Name: stroke, dtype: float64

# %%
categorical = [col for col in df.columns if df[col].dtype == "O"]
categorical.remove("stroke")
print(categorical)
# Out:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
numerical = [col for col in df.columns if df[col].dtype != "O"]
numerical = numerical[0:-1]
numerical
# Out:
# ['age', 'hypertension', 'heart_disease', 'avg_glucose_level']

# %%
X = df.drop('stroke', axis=1)
Y = df['stroke']

X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size=0.15, random_state=42, stratify=Y)

# %%
train_data = pd.concat([X_train,Y_train], axis=1)
train_data = train_data[train_data.stroke == "Healthy"]
train_data.head()
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 4625  Female  34.0             0              0           No       Govt_job
# 2117    Male  21.0             0              0           No  Self-employed
# 1131  Female  47.0             0              0          Yes        Private
# 736   Female  20.0             0              0          Yes        Private
# 620     Male  33.0             0              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi smoking_status   stroke
# 4625          Urban             226.28  38.4        Unknown  Healthy
# 2117          Urban              92.87  37.0   never smoked  Healthy
# 1131          Rural             195.04  45.5   never smoked  Healthy
# 736           Urban              74.02  22.3   never smoked  Healthy
# 620           Rural             219.97  39.6   never smoked  Healthy

# %%
train_data.stroke.value_counts()
# Out:
# Healthy    4130
# Name: stroke, dtype: int64

# %%
Y_test = Y_test.map({"Healthy" : 0 , "Stroke" : 1 })
Y_train = Y_train.map({"Healthy" : 0 , "Stroke" : 1 })

# %%
pipeline = ColumnTransformer([("scaler", StandardScaler() ,numerical ),
                               ("encoder", OneHotEncoder() , categorical)
                             ])

train_data = pipeline.fit_transform(train_data)
X_test = pipeline.transform(X_test) 
X_train = pipeline.transform(X_train)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='minority')
X_resampled, y_resampled = smote.fit_resample(X_train, Y_train)

# %%
list(y_resampled).count(0), list(y_resampled).count(1)
# Out:
# (4130, 4130)

# %%
joblib.dump(pipeline, "pipeline.joblib")
# Out:
# ['pipeline.joblib']

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Modeling</h3>

# %%
models = {"tree":DecisionTreeClassifier(),
          "XGB" : XGBClassifier(), "SVM":SVC()}

# %%
for name, model in models.items():
    print("\n\n\n\n",name)
    model.fit(X_train, Y_train)
    
    print(F"Training Accuracy is {model.score(X_train, Y_train)}")
    Y_pred = model.predict(X_test)
    print(f"Accuracy Score is {accuracy_score(Y_pred, Y_test)}")
    Y_pred_train = model.predict(X_train)
    
    print(f"Training F1 Score is {f1_score(Y_pred_train, Y_train)}")

    print(f"Testing F1 Score is {f1_score(Y_pred, Y_test)}")
    print(classification_report(Y_test, Y_pred))  
    # specify axis with  figure size 
    fig,ax = plt.subplots(figsize=(7,7))
    # getting confusion matrix
    confusion = confusion_matrix(Y_test, Y_pred)
    # confusionMatraxDisplay is used to create a confusion matrix plot from confusion
    display_con = ConfusionMatrixDisplay(confusion,display_labels=['Normal',"CHD"])
    # the confusion matrix with respect to axis defined above
    display_con.plot(ax=ax)
    plt.show()
# Out:
#  tree
# Training Accuracy is 1.0
# Accuracy Score is 0.9139504563233377
# Training F1 Score is 1.0
# Testing F1 Score is 0.10810810810810811
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       730
#            1       0.11      0.11      0.11        37
#
#     accuracy                           0.91       767
#    macro avg       0.53      0.53      0.53       767
# weighted avg       0.91      0.91      0.91       767
#  XGB
# Training Accuracy is 0.9859511745739291
# Accuracy Score is 0.9478487614080835
# Training F1 Score is 0.8319559228650137
# Testing F1 Score is 0.09090909090909091
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       730
#            1       0.29      0.05      0.09        37
#
#     accuracy                           0.95       767
#    macro avg       0.62      0.52      0.53       767
# weighted avg       0.92      0.95      0.93       767
#  SVM
# Training Accuracy is 0.9511745739290649
# Accuracy Score is 0.9517601043024772
# Training F1 Score is 0.0
# Testing F1 Score is 0.0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       730
#            1       0.00      0.00      0.00        37
#
#     accuracy                           0.95       767
#    macro avg       0.48      0.50      0.49       767
# weighted avg       0.91      0.95      0.93       767
# C:\Users\Ahmed-Basem\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ahmed-Basem\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ahmed-Basem\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Anomaly Detection

# %%
Y_test = Y_test.map({0 : 1 ,  1 : -1 })
Y_train = Y_train.map({0 : 1 ,  1 : -1 })

# %%
list(Y_test).count(1) , list(Y_test).count(-1)
# Out:
# (730, 37)

# %%
from sklearn import svm

model = svm.OneClassSVM()  
model.fit(train_data)
y_pred = model.predict(X_test)

# %%
Y_test = Y_test.map({1 : 0 ,  -1 : 1 })
y_pred = pd.Series(y_pred).map({1 : 0 ,  -1 : 1 })
f1_score(y_pred, Y_test)
# Out:
# 0.13394919168591224

# %%
import optuna

# %%
def objective(trial):
    
    nu = trial.suggest_uniform('nu', 0.01, 0.5)

    model = svm.OneClassSVM(nu=nu)

    
    model.fit(train_data)
    
    y_pred = model.predict(X_test)
    
    # Y_test = Y_test.map({1 : 0 ,  -1 : 1 })
    y_pred = pd.Series(y_pred).map({1 : 0 ,  -1 : 1 })

    score = f1_score(y_pred, Y_test)
    
    return score

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=25)

best_params = study.best_params
best_nu = best_params['nu']

print(f"Best nu: {best_nu}")
# Out:
# [I 2023-12-15 22:06:14,124] A new study created in memory with name: no-name-4373291e-5827-4382-8340-67575bbb9855
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:14,202] Trial 0 finished with value: 0.1647058823529412 and parameters: {'nu': 0.05678610016891261}. Best is trial 0 with value: 0.1647058823529412.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:14,382] Trial 1 finished with value: 0.1851851851851852 and parameters: {'nu': 0.15829020472743874}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:14,620] Trial 2 finished with value: 0.18446601941747573 and parameters: {'nu': 0.21962672635265373}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:14,723] Trial 3 finished with value: 0.18518518518518517 and parameters: {'nu': 0.0843060206713364}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:14,851] Trial 4 finished with value: 0.18461538461538463 and parameters: {'nu': 0.10884342054493659}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:15,210] Trial 5 finished with value: 0.14420062695924765 and parameters: {'nu': 0.3494740362336491}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:15,562] Trial 6 finished with value: 0.14743589743589744 and parameters: {'nu': 0.34041637662790536}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:15,823] Trial 7 finished with value: 0.17674418604651163 and parameters: {'nu': 0.2368771164799704}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:16,213] Trial 8 finished with value: 0.14067278287461774 and parameters: {'nu': 0.36818947100243565}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:16,307] Trial 9 finished with value: 0.16326530612244897 and parameters: {'nu': 0.07320247944302515}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:16,763] Trial 10 finished with value: 0.14105793450881615 and parameters: {'nu': 0.4522652182994402}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:16,936] Trial 11 finished with value: 0.1794871794871795 and parameters: {'nu': 0.14440403862430234}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:16,975] Trial 12 finished with value: 0.10526315789473685 and parameters: {'nu': 0.013523075035273377}. Best is trial 1 with value: 0.1851851851851852.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:17,153] Trial 13 finished with value: 0.1863354037267081 and parameters: {'nu': 0.15622018228429385}. Best is trial 13 with value: 0.1863354037267081.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:17,347] Trial 14 finished with value: 0.1904761904761905 and parameters: {'nu': 0.16948960070541955}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:17,553] Trial 15 finished with value: 0.18497109826589594 and parameters: {'nu': 0.17988415237058952}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:17,839] Trial 16 finished with value: 0.15767634854771784 and parameters: {'nu': 0.2657807876532364}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:18,055] Trial 17 finished with value: 0.1787709497206704 and parameters: {'nu': 0.19158590240328757}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:18,199] Trial 18 finished with value: 0.18571428571428572 and parameters: {'nu': 0.12028506573426523}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:18,504] Trial 19 finished with value: 0.1484375 and parameters: {'nu': 0.27499409860127794}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:18,681] Trial 20 finished with value: 0.189873417721519 and parameters: {'nu': 0.14950981416365808}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:18,851] Trial 21 finished with value: 0.1794871794871795 and parameters: {'nu': 0.14448994178385147}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:19,073] Trial 22 finished with value: 0.1878453038674033 and parameters: {'nu': 0.19366479827128139}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:19,300] Trial 23 finished with value: 0.18947368421052632 and parameters: {'nu': 0.20261975817118727}. Best is trial 14 with value: 0.1904761904761905.
# C:\Users\Ahmed-Basem\AppData\Local\Temp\ipykernel_4760\293560947.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   nu = trial.suggest_uniform('nu', 0.01, 0.5)
# [I 2023-12-15 22:06:19,551] Trial 24 finished with value: 0.18446601941747573 and parameters: {'nu': 0.22286223085100748}. Best is trial 14 with value: 0.1904761904761905.
# Best nu: 0.16948960070541955

# %%
final_model = svm.OneClassSVM(nu=best_nu)

# %%
final_model.fit(train_data)
y_pred = final_model.predict(X_test)

# %%
Y_test = Y_test.map({1 : 0 ,  -1 : 1 })
y_pred = pd.Series(y_pred).map({1 : 0 ,  -1 : 1 })

# %%
print(f"Precision Score {precision_score(Y_test,y_pred)}")
print(f"Recall Score {recall_score(Y_test,y_pred)}")
print(f"F1 Score is {f1_score(Y_test,y_pred)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4760\884293950.py in <module>
# ----> 1 print(f"Precision Score {precision_score(Y_test,y_pred)}")
#       2 print(f"Recall Score {recall_score(Y_test,y_pred)}")
#       3 print(f"F1 Score is {f1_score(Y_test,y_pred)}")
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1774     array([0.5, 1. , 1. ])
#    1775     """
# -> 1776     p, _, _, _ = precision_recall_fscore_support(
#    1777         y_true,
#    1778         y_pred,
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1561     if beta < 0:
#    1562         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1563     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1564
#    1565     # Calculate tp_sum, pred_sum, true_sum ###
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1362         raise ValueError("average has to be one of " + str(average_options))
#    1363
# -> 1364     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1365     # Convert to Python primitive type to avoid NumPy type / Python str
#    1366     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      83     """
#      84     check_consistent_length(y_true, y_pred)
# ---> 85     type_true = type_of_target(y_true, input_name="y_true")
#      86     type_pred = type_of_target(y_pred, input_name="y_pred")
#      87
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y, input_name)
#     330     if y.dtype.kind == "f" and np.any(y != y.astype(int)):
#     331         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 332         _assert_all_finite(y, input_name=input_name)
#     333         return "continuous" + suffix
#     334
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input y_true contains NaN.

# %%
print(classification_report(Y_test, y_pred))  
# specify axis with  figure size 
fig,ax = plt.subplots(figsize=(7,7))
# getting confusion matrix
confusion = confusion_matrix(Y_test, y_pred)
# confusionMatraxDisplay is used to create a confusion matrix plot from confusion
display_con = ConfusionMatrixDisplay(confusion,display_labels=["CHD","Normal"])
# the confusion matrix with respect to axis defined above
display_con.plot(ax=ax)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       730
#            1       0.11      0.08      0.09        37
#
#     accuracy                           0.92       767
#    macro avg       0.53      0.52      0.53       767
# weighted avg       0.91      0.92      0.92       767

# %%
TN = confusion[1, 1]
FP = confusion[1, 0]
FN = confusion[0, 1]
TP = confusion[0, 0]

# %%
TPR = TP / (TP + FN)
print(f"True Positive Rate is {round(TPR * 100)} %")

FPR = FP / (FP + TN)
print("False Positive Rate:", round(FPR * 100) , "%")
# Out:
# True Positive Rate is 22 %
# False Positive Rate: 7 %

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Data Correlation</h3>

# %%
df['gender'] = df['gender'].map({'Male' : 1 , 'Female' : 0})

df['ever_married'] = df['ever_married'].map({'Yes' : 1 , 'No' : 0})

df['work_type'] = df['work_type'].map({'Private' : 1 , 'Self-employed' : 2 ,
                                       'Govt_job' : 3     , 'children' : 4 , 'Never_worked' : 5 }) 

df['Residence_type'] = df['Residence_type'].map({'Urban' : 1 , 'Rural' : 2})

df['smoking_status'] = df['smoking_status'].map({'never smoked' : 1 , 'smokes' : 2 ,
                                       'formerly smoked' : 3     , 'Unknown' : 4 })

# %%
df.corr()
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000 -0.027752      0.021223       0.085685
# age               -0.027752  1.000000      0.276367       0.263777
# hypertension       0.021223  0.276367      1.000000       0.108292
# heart_disease      0.085685  0.263777      0.108292       1.000000
# ever_married      -0.030171  0.679084      0.164187       0.114601
# work_type          0.065848 -0.413428     -0.075150      -0.058301
# Residence_type     0.006105 -0.014031      0.007980      -0.003045
# avg_glucose_level  0.054722  0.238323      0.174540       0.161907
# bmi               -0.026452  0.324211      0.158252       0.036879
# smoking_status     0.094314 -0.250318     -0.110418      -0.020187
# stroke             0.009081  0.245239      0.127891       0.134905
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                -0.030171   0.065848        0.006105           0.054722
# age                    0.679084  -0.413428       -0.014031           0.238323
# hypertension           0.164187  -0.075150        0.007980           0.174540
# heart_disease          0.114601  -0.058301       -0.003045           0.161907
# ever_married           1.000000  -0.376238       -0.005988           0.155329
# work_type             -0.376238   1.000000       -0.014426          -0.068023
# Residence_type        -0.005988  -0.014426        1.000000           0.004783
# avg_glucose_level      0.155329  -0.068023        0.004783           1.000000
# bmi                    0.334770  -0.341665        0.000444           0.167033
# smoking_status        -0.230048   0.309608       -0.010290          -0.058142
# stroke                 0.108299  -0.058261       -0.015415           0.131991
#
#                         bmi  smoking_status    stroke
# gender            -0.026452        0.094314  0.009081
# age                0.324211       -0.250318  0.245239
# hypertension       0.158252       -0.110418  0.127891
# heart_disease      0.036879       -0.020187  0.134905
# ever_married       0.334770       -0.230048  0.108299
# work_type         -0.341665        0.309608 -0.058261
# Residence_type     0.000444       -0.010290 -0.015415
# avg_glucose_level  0.167033       -0.058142  0.131991
# bmi                1.000000       -0.203276  0.036075
# smoking_status    -0.203276        1.000000 -0.019756
# stroke             0.036075       -0.019756  1.000000

# %%
plt.figure(figsize=(17,13))
sns.heatmap(df.corr(), annot=True, annot_kws={"size": 13},cmap='Blues')
plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Deployment</h3>
