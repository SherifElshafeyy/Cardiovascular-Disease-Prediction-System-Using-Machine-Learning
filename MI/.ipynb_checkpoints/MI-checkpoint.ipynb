# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:#2eddc6;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;"> CK-MB & Troponin Tests Notebook </h1>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Introduction</h3>

# %% [markdown]
# Cardiac emergencies are the leading cause of mortality worldwide. In a cardiac emergency, the two pillars that facilitate the right diagnosis and treatment are; the time and accuracy of every verbal or diagnostic information. Both of these have a critical effect on the outcomes of the cardiac patient.
#
# CK-MB and troponin tests are essential diagnostic tools for heart attack evaluation. These tests provide valuable information about the presence, extent, and progression of heart muscle damage, enabling prompt diagnosis, appropriate treatment, and effective monitoring of heart health.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Vision</h3>

# %% [markdown]
# Our vision involves integrating the troponin test and CK-MB results with the analysis of 12-lead ECG to enhance our ability to detect **MI (heart attack)** and identify any abnormalities. By combining these diagnostic factors, we aim to create a comprehensive and robust system that leverages multiple sources of information to improve the accuracy and reliability of our detection model.
#
# The **troponin test** measures the level of troponin, a protein found in the cells of the heart muscle, in a person's blood. Elevated troponin levels indicate damage to the heart muscle, such as that caused by a heart attack.
#
# Additionally, we will incorporate the **CK-MB test**, which looks for a specific enzyme in the blood to diagnose or rule out a heart attack. Although the CK-MB test is no longer the primary choice for diagnosing heart attacks, it can still provide relevant information when combined with other diagnostic factors.
#
# By considering CK-MB results alongside the troponin test and 12-lead ECG analysis, we can gain a more comprehensive understanding of a person's cardiac health.
#
# By combining these diagnostic factors together through detection approach in our project, our vision is to develop a system that provides an in-depth and accurate assessment of a person's risk of MI and identifies any abnormalities in their cardiac health. This integrated approach will enable us to deliver more **reliable results** and facilitate timely medical intervention and treatment, ultimately improving patient outcomes.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Data Overview</h3>

# %% [markdown]
#  This heart attack dataset was collected at Zheen hospital in Erbil, Iraq, from January 2019 to May 2019.
#
# According to the provided information, the medical dataset classifies either heart attack or none. The gender column in the data is normalized: the male is set to 1 and the female to 0. As for the output, positive is set to 1 and negative to 0.

# %% [markdown]
# |         Column       |                             Description                            |
# |:-------------------:|:---------------------------------------------------------------:|
# |         Age         |                Age of the patient (Continuous)                      |
# |         Gender        |                Male or female (Nominal)                            |
# |     Heart Rate      |     Heart rate (Continuous - In medical research, variables such as heart rate though in fact discrete, yet are considered continuous because of the large number of possible values) |
# |       Systolic Blood Pressure        |     Systolic blood pressure (Continuous)                            |
# |       Diastolic Blood Pressure        |     Diastolic blood pressure (Continuous)                           |
# |       Blood Sugar      |     Blood Sugar level (Continuous)                                      |
# |      CK-MB      |     CK-MB level (Continuous)                            |
# |         Troponin         |     Troponin level (Continuous)                                    |
# |Result| Binary variable indicating whether the patient has a risk of Myocardial Infarction (MI) (Binary: "1" means "Yes", "0" means "No") |

# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Medical Background </h1>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Cardiovascular systemt</h3>

# %% [markdown]
# The cardiovascular system, also known as the circulatory system, is a vital network of organs, vessels, and tissues responsible for transporting blood, oxygen, nutrients, and waste products throughout the body. It plays a crucial role in maintaining homeostasis and supporting various bodily functions. The key components of the cardiovascular system include the heart, blood vessels, and blood.

# %%
from IPython.display import Image
Image(filename='Human-Circulatory-System-Transportation.png',width=900,height=400)

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Myocardial Infarction (MI)</h3>

# %% [markdown]
# A myocardial infarction (MI), commonly known as a heart attack, is an extremely dangerous condition that occurs when blood flow decreases or stops in one of the coronary arteries of the heart, causing infarction (tissue death) to the heart muscle.

# %%
Image(filename='Heart Attack.jpg',width=900,height=400)

# %% [markdown]
# Most MIs occur due to coronary artery disease ,which is considered a crucial concern that we have also worked on through the Framingham heart study dataset through our graduation project,.
#
# Risk factors of MI include family history of heart disease, high blood pressure, smoking, diabetes, lack of exercise, obesity, high blood cholesterol.

# %%
Image(filename='MI.png',width=900,height=400)

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Troponin Test</h3>

# %% [markdown]
# A troponin test measures the level of troponin in a sample of your blood. Troponin is a protein that's found in the cells of your heart muscle.
#
# Normally, troponin levels in blood are so low that only the most sensitive types of tests can measure them. But if your heart muscle is damaged, troponin leaks into your bloodstream, and your troponin blood levels will rise.
#
# Troponin testing is mainly used to help diagnose heart attacks. Heart attacks damage the heart by suddenly blocking the blood flow that brings oxygen to part of the heart muscle. Without oxygen from blood, heart muscle cells die and release troponin.
#
# Troponin test results can confirm damage to the heart muscle from a heart attack. The more damage there is to the heart, the more troponin is released into the blood. So, measuring the amount of troponin in the blood can also help estimate how much of the heart has been damaged. Higher than normal troponin levels may also be found in other conditions that can damage heart muscle.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">What is it used for?</h3>

# %% [markdown]
# - Confirm if a person is having a heart attack or recently had a heart attack. This is the most common reason for troponin testing. The test is usually done in the emergency room of a hospital along with other heart tests, such as an EKG (also called an ECG or electrocardiogram).
# - Diagnose and monitor unstable angina. Angina is chest pain that happens if part of the heart muscle doesn't get as much blood as it needs. Unstable angina is a type of angina that happens at any time, even during rest. It's a medical emergency because it can lead to a heart attack.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">CK-MB Test</h3>

# %% [markdown]
# The CK-MB test is a test that looks for a specific type of enzyme in your blood to diagnose or rule out a heart attack. However, CK-MB is no longer the blood test of choice for diagnosing heart attacks, and many hospitals no longer use it because there are better test methods available (the cardiac troponin tests are currently the tests of choice).

# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;"> Libraries & loading the data</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
import scipy.stats as stats
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Load the dataset
df = pd.read_csv("MI.csv")

# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;"> Exploratory Data Analysis</h1>

# %%
print(f'No. of records are {df.shape[0]}')
print(f'No. of columns are {df.shape[1]}')
# Out:
# No. of records are 1319
# No. of columns are 9

# %%
df.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %%
column = list(df.columns)
categorical_features = []
discrete_features = []

for i in column:
    if len(df[i].unique()) > 6:
        discrete_features.append(i)
    else:
        categorical_features.append(i)

print('Categorical Features :',*categorical_features)
print('Continous Features :',*discrete_features)
# Out:
# Categorical Features : Gender Result
# Continous Features : Age Heart rate Systolic blood pressure Diastolic blood pressure Blood sugar CK-MB Troponin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
round(df.describe())
# Out:
#           Age  Gender  Heart rate  Systolic blood pressure  \
# count  1319.0  1319.0      1319.0                   1319.0
# mean     56.0     1.0        78.0                    127.0
# std      14.0     0.0        52.0                     26.0
# min      14.0     0.0        20.0                     42.0
# 25%      47.0     0.0        64.0                    110.0
# 50%      58.0     1.0        74.0                    124.0
# 75%      65.0     1.0        85.0                    143.0
# max     103.0     1.0      1111.0                    223.0
#
#        Diastolic blood pressure  Blood sugar   CK-MB  Troponin
# count                    1319.0       1319.0  1319.0    1319.0
# mean                       72.0        147.0    15.0       0.0
# std                        14.0         75.0    46.0       1.0
# min                        38.0         35.0     0.0       0.0
# 25%                        62.0         98.0     2.0       0.0
# 50%                        72.0        116.0     3.0       0.0
# 75%                        81.0        170.0     6.0       0.0
# max                       154.0        541.0   300.0      10.0

# %%
# Remove duplicates if any
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %%
# Mapping the categorical toarget to 1 if positive and 0 if negative
df['MI'] = df['Result'].map({'positive': 1, 'negative': 0})

# %%
df=df.drop('Result',axis=1)

# %%
df['Gender'] = df['Gender'].map({1 : 'male', 0 : 'female'})

# %%
df.to_csv("updated_MI.csv")

# %%
df.head()
# Out:
#    Age Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64   male          66                      160                        83
# 1   21   male          94                       98                        46
# 2   55   male          64                      160                        77
# 3   64   male          70                      120                        55
# 4   55   male          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin  MI
# 0        160.0   1.80     0.012   0
# 1        296.0   6.75     1.060   1
# 2        270.0   1.99     0.003   0
# 3        270.0  13.87     0.122   1
# 4        300.0   1.08     0.003   0

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Target distribution</h3>

# %%
# let us overview the distribution of the target of our data
x = pd.DataFrame(df.groupby(['MI'])['MI'].count())

# Plot
fig, ax = plt.subplots(figsize=(7, 7), dpi=60)
ax.barh([1], x.MI[1], height=0.7, color='#875692')
plt.text(-200, -0.08, 'Healthy', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'style': 'normal', 'color': '#4ccfbe'})
plt.text(900, -0.08, '38.6%', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'color': '#4ccfbe'})
ax.barh([0], x.MI[0], height=0.7, color='#4ccfbe')
plt.text(-100, 1, 'MI', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'style': 'normal', 'color': '#875692'})
plt.text(900, 1, '61.4%', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'color': '#875692'})

fig.patch.set_facecolor('white')
ax.set_facecolor('white')

plt.text(-1150, 1.77, 'Percentage of People at Risk of Myocardial Infarction (MI)', {'font': 'Serif', 'size': '25', 'weight': 'bold', 'color': 'black'})

ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Data Visualization Functions</h3>

# %% [markdown]
# There are many different types of graphs, each with its own unique properties and applications.
#
# We will use :
#
# 1- **Pie plot** : for categorical data
#
# 2- **KDE plot** : (kernel density estimation plot) : for numerical data
#
# 3- **Box Plot** : for definition of outliers in numerical data
#
# 4- **Histogram** : distribution of numerical data

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Catigorical data</h3>

# %%
def pie_plot(df, group_feature, overall_title, colors):
    # Calculate percentage of each category in the group feature
    grouped = df[group_feature].value_counts(normalize=True).rename('percentage').mul(100).reset_index()

    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(figsize=(8, 6))

        wedges, texts, autotexts = ax.pie(grouped['percentage'], labels=grouped['index'],
                                           autopct='%1.1f%%', colors=colors)
        ax.set_title(f'Distribution of {overall_title}')  # Set the title to be the group feature
        plt.setp(autotexts, size=16, color="w")

        plt.tight_layout()
        plt.show()

# %%
def pie_with_target(df, group_feature, overall_title):
    # Calculate percentage of people who developed MI for each group
    grouped = df.groupby(group_feature)['MI'].value_counts(normalize=True).rename('percentage').mul(100).reset_index()

    # Define custom color palette
    custom_palette = {0: '#4ccfbe', 1: '#875692'}
    # Define custom legend labels
    legend_labels = {0: 'Negative', 1: 'Positive'}

    unique_groups = grouped[group_feature].unique()
    num_unique_groups = len(unique_groups)

    # Ensure all MI statuses are in custom_palette and legend_labels
    assert set(grouped['MI'].unique()).issubset(custom_palette.keys()), "All MI statuses must be keys in custom_palette"
    assert set(grouped['MI'].unique()).issubset(legend_labels.keys()), "All MI statuses must be keys in legend_labels"

    with plt.style.context('fivethirtyeight'):
        fig, axs = plt.subplots(1, num_unique_groups, figsize=(15, 6))

        if num_unique_groups == 1:
            axs = [axs]  # To handle the case where there is only 1 group

        for i, group_status in enumerate(unique_groups):
            data = grouped[grouped[group_feature]== group_status ]
            labels = data['MI'].map(legend_labels).tolist() # map stroke status to labels
            colors = data['MI'].map(custom_palette).tolist() # map stroke status to colors
            wedges, texts, autotexts = axs[i].pie(data['percentage'], labels=labels, colors=colors, autopct='%1.1f%%')

            axs[i].set_title(f'{group_status}')  # Set the title to be the group feature and status
            plt.setp(autotexts, size=16, color="w")
        
        
        fig.suptitle(f'Percentage of people who developed MI grouped by {overall_title} status', fontsize=18)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Continuous data</h3>

# %%
def plot_distribution(df, feature, plot_title):
    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(1, 2, figsize=(20, 5))

        # Histogram
        sns.histplot(x=feature,
                     data=df, 
                     ax=ax[0],
                     linewidth=0.8,
                     color='#4ccfbe',
                     bins=20).set_title(f"Distribution of {plot_title}")
        ax[0].set_xlabel(plot_title)

        # Box plot for the entire distribution
        sns.boxplot(x=feature,
                    data=df,
                    linewidth=1.5,
                    width=0.5,
                    color='#4ccfbe',
                    ax=ax[1]).set_title(f"Box Plot of {plot_title}")
        ax[1].set_xlabel(plot_title)

        plt.show()

# %%
df['MI'] = df['MI'].map({1: 'MI', 0: 'Healthy'})
def plot_MI_vs_Healthy(feature, plot_title, df = df):
    box_plots_colors = {'Healthy': '#4ccfbe', 'MI':'#875692'}
    
    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(1, 2, figsize=(20, 5))

        # KDE plot for MI vs Healthy
        sns.kdeplot(data=df[df['MI']=='MI'], x=feature, color='#875692', fill=True, linewidth=1.5, ec='black', alpha=0.8, zorder=3, ax=ax[0])
        sns.kdeplot(data=df[df['MI']=='Healthy'], x=feature, color='#4ccfbe', fill=True, linewidth=1.5, ec='black', alpha=0.8, zorder=3, ax=ax[0])

        ax[0].set_title(f"KDE Plot of {plot_title} by MI")
        ax[0].set_xlabel(plot_title)
        ax[0].set_ylabel('Density')

        # Box plot for MI vs Healthy
        sns.boxplot(x=feature,
                    data=df,
                    y="MI",
                    linewidth=1.5,
                    palette=box_plots_colors,
                    ax=ax[1]).set_title(f"Distribution of {plot_title} by MI")
        ax[1].set_xlabel(plot_title)
        ax[1].set_ylabel('MI')

        plt.show()

# %% [markdown]
# # <a id="2.2"></a>
# <h3 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Feature Statistics Functions</h3>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Catigorical data</h3>

# %%
def explore_categorical_variable(feature, data = df):
    # Extract the column from the dataset
    column = data[feature]
    
    # Data type
    data_type = column.dtype
    
    # Count of each category
    count = column.count()
    
    # Mode (most frequent category)
    mode = column.mode().iloc[0]
    
    unique_values = column.nunique()
    
    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Data Type', 'Count', 'Mode', 'Num of Possible values'],
        'Values': [data_type, count,  mode , unique_values ]
    })
    
    # Remove the index column
    results_df = results_df.reset_index(drop=True)
    
    return results_df

# %%
def explore_categories(feature_name, category_names, data=df):
    
    # Extract the column from the dataset
    column = data[feature_name]

    # Data type
    data_type = str(column.dtype)

    # Count of each category
    category_counts = column.value_counts()

    # Percentage of each category
    category_percentages = {category: count / column.count() * 100 for category, count in category_counts.items()}

    # Create a DataFrame for count, percentage, data type, and mode
    result_df = pd.DataFrame({
        f'{feature_name}': category_counts.index,
        'Count': category_counts.values,
        'Percentage': [category_percentages.get(category, 0) for category in category_counts.index],
    })

    # Formatting for Percentage column
    result_df['Percentage'] = result_df['Percentage'].round(2)

    return result_df

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Continuous data</h3>

# %%
def explore_continuous_variable(feature, data=df):
    # Extract the column from the dataset
    column = data[feature]
    
    # Data type
    data_type = column.dtype
    
    # Basic statistics
    minimum = int(column.min())
    maximum = int(column.max())
    data_range = maximum - minimum
    mean = round(column.mean())
    median = int(column.median())
    q3 = int(column.quantile(0.75))
    q1 = int(column.quantile(0.25))
    iqr = q3 - q1
    variance = round(column.var(), 2)
    std_deviation = round(column.std(), 2)
    coefficient_of_variation = round(np.sqrt(variance) / mean, 2)
    skewness = round(column.skew(), 2)
    
    # Percentiles
    percentiles = column.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])
    
    # Number of null values
    num_null_values = column.isnull().sum()
    
    # Calculate outliers based on IQR
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers_percentage = round(((column < lower_bound) | (column > upper_bound)).mean() * 100, 2)
    
    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Feature', 'Data Type', 'Minimum Value', 'Maximum Value', 'Range', 'Mean', 'Median', 'Q3', 'Q1',
                       'IQR', 'Outliers Percentage', 'Variance', 'Standard Deviation', 'Coefficient of Variation', 'Skewness',
                       '10th Percentile', '25th Percentile', '50th Percentile', '75th Percentile', '90th Percentile',
                       'Number of Null Values','Lower Band' , 'Upper Band'],
        'Values': [feature, data_type, minimum, maximum, data_range, mean, median, q3, q1, iqr, outliers_percentage, variance, std_deviation,
                   coefficient_of_variation, skewness, int(percentiles['10%']), int(percentiles['25%']),
                   int(percentiles['50%']), int(percentiles['75%']), int(percentiles['90%']), num_null_values , lower_bound , upper_bound  
                   ]
    })
    
    results_df = results_df.reset_index(drop=True)
    
    # Create a Styler object
    styled_df = results_df.style.set_properties(**{'text-align': 'center'})
    
    return styled_df

# %%
def compare_feature_statistics(feature, data=df):
    # Extract the column for MI and Healthy individuals
    MI_column = data[data['MI'] == 1][feature]
    healthy_column = data[data['MI'] == 0][feature]

    # Basic statistics for MI
    MI_mean = int(MI_column.mean())
    MI_median = int(MI_column.median())
    MI_std_deviation = round(MI_column.std(), 2)
    MI_min = int(MI_column.min())
    MI_max = int(MI_column.max())
    MI_iqr = int(MI_column.quantile(0.75) - MI_column.quantile(0.25))

    # Basic statistics for Healthy
    healthy_mean = int(healthy_column.mean())
    healthy_median = int(healthy_column.median())
    healthy_std_deviation = round(healthy_column.std(), 2)
    healthy_min = int(healthy_column.min())
    healthy_max = int(healthy_column.max())
    healthy_iqr = int(healthy_column.quantile(0.75) - healthy_column.quantile(0.25))

    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Mean', 'Median', 'Std Deviation', 'Min', 'Max', 'IQR'],
        'MI': [MI_mean, MI_median, MI_std_deviation, MI_min, MI_max, MI_iqr],
        'Healthy': [healthy_mean, healthy_median, healthy_std_deviation, healthy_min, healthy_max, healthy_iqr]
    })

    results_df = results_df.set_index('Statistics')
    
    results_df = results_df.astype(int)

    # Create a Styler object
    styled_df = results_df.style.set_properties(**{'text-align': 'center'})

    return styled_df

# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;"> Features</h1>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Age</h3>

# %%
explore_continuous_variable('Age')
# Out:
# <style  type="text/css" >
# #T_f509a_row0_col0,#T_f509a_row0_col1,#T_f509a_row1_col0,#T_f509a_row1_col1,#T_f509a_row2_col0,#T_f509a_row2_col1,#T_f509a_row3_col0,#T_f509a_row3_col1,#T_f509a_row4_col0,#T_f509a_row4_col1,#T_f509a_row5_col0,#T_f509a_row5_col1,#T_f509a_row6_col0,#T_f509a_row6_col1,#T_f509a_row7_col0,#T_f509a_row7_col1,#T_f509a_row8_col0,#T_f509a_row8_col1,#T_f509a_row9_col0,#T_f509a_row9_col1,#T_f509a_row10_col0,#T_f509a_row10_col1,#T_f509a_row11_col0,#T_f509a_row11_col1,#T_f509a_row12_col0,#T_f509a_row12_col1,#T_f509a_row13_col0,#T_f509a_row13_col1,#T_f509a_row14_col0,#T_f509a_row14_col1,#T_f509a_row15_col0,#T_f509a_row15_col1,#T_f509a_row16_col0,#T_f509a_row16_col1,#T_f509a_row17_col0,#T_f509a_row17_col1,#T_f509a_row18_col0,#T_f509a_row18_col1,#T_f509a_row19_col0,#T_f509a_row19_col1,#T_f509a_row20_col0,#T_f509a_row20_col1,#T_f509a_row21_col0,#T_f509a_row21_col1,#T_f509a_row22_col0,#T_f509a_row22_col1{
#             text-align:  center;
#         }</style><table id="T_f509a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Statistics</th>        <th class="col_heading level0 col1" >Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f509a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f509a_row0_col0" class="data row0 col0" >Feature</td>
#                         <td id="T_f509a_row0_col1" class="data row0 col1" >Age</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f509a_row1_col0" class="data row1 col0" >Data Type</td>
#                         <td id="T_f509a_row1_col1" class="data row1 col1" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f509a_row2_col0" class="data row2 col0" >Minimum Value</td>
#                         <td id="T_f509a_row2_col1" class="data row2 col1" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f509a_row3_col0" class="data row3 col0" >Maximum Value</td>
#                         <td id="T_f509a_row3_col1" class="data row3 col1" >103</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f509a_row4_col0" class="data row4 col0" >Range</td>
#                         <td id="T_f509a_row4_col1" class="data row4 col1" >89</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f509a_row5_col0" class="data row5 col0" >Mean</td>
#                         <td id="T_f509a_row5_col1" class="data row5 col1" >56</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f509a_row6_col0" class="data row6 col0" >Median</td>
#                         <td id="T_f509a_row6_col1" class="data row6 col1" >58</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f509a_row7_col0" class="data row7 col0" >Q3</td>
#                         <td id="T_f509a_row7_col1" class="data row7 col1" >65</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f509a_row8_col0" class="data row8 col0" >Q1</td>
#                         <td id="T_f509a_row8_col1" class="data row8 col1" >47</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f509a_row9_col0" class="data row9 col0" >IQR</td>
#                         <td id="T_f509a_row9_col1" class="data row9 col1" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f509a_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#                         <td id="T_f509a_row10_col1" class="data row10 col1" >0.530000</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f509a_row11_col0" class="data row11 col0" >Variance</td>
#                         <td id="T_f509a_row11_col1" class="data row11 col1" >186.250000</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f509a_row12_col0" class="data row12 col0" >Standard Deviation</td>
#                         <td id="T_f509a_row12_col1" class="data row12 col1" >13.650000</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f509a_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#                         <td id="T_f509a_row13_col1" class="data row13 col1" >0.240000</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f509a_row14_col0" class="data row14 col0" >Skewness</td>
#                         <td id="T_f509a_row14_col1" class="data row14 col1" >-0.240000</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f509a_row15_col0" class="data row15 col0" >10th Percentile</td>
#                         <td id="T_f509a_row15_col1" class="data row15 col1" >38</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f509a_row16_col0" class="data row16 col0" >25th Percentile</td>
#                         <td id="T_f509a_row16_col1" class="data row16 col1" >47</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f509a_row17_col0" class="data row17 col0" >50th Percentile</td>
#                         <td id="T_f509a_row17_col1" class="data row17 col1" >58</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_f509a_row18_col0" class="data row18 col0" >75th Percentile</td>
#                         <td id="T_f509a_row18_col1" class="data row18 col1" >65</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_f509a_row19_col0" class="data row19 col0" >90th Percentile</td>
#                         <td id="T_f509a_row19_col1" class="data row19 col1" >72</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_f509a_row20_col0" class="data row20 col0" >Number of Null Values</td>
#                         <td id="T_f509a_row20_col1" class="data row20 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f509a_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_f509a_row21_col0" class="data row21 col0" >Lower Band</td>
#                         <td id="T_f509a_row21_col1" class="data row21 col1" >20.000000</td>
#             </tr>

# %%
plot_distribution(df, 'Age', 'Age')

# %%
compare_feature_statistics('Age')
# Out:
# <style  type="text/css" >
# #T_c2133_row0_col0,#T_c2133_row0_col1,#T_c2133_row1_col0,#T_c2133_row1_col1,#T_c2133_row2_col0,#T_c2133_row2_col1,#T_c2133_row3_col0,#T_c2133_row3_col1,#T_c2133_row4_col0,#T_c2133_row4_col1,#T_c2133_row5_col0,#T_c2133_row5_col1{
#             text-align:  center;
#         }</style><table id="T_c2133_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2133_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_c2133_row0_col0" class="data row0 col0" >58</td>
#                         <td id="T_c2133_row0_col1" class="data row0 col1" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_c2133_level0_row1" class="row_heading level0 row1" >Median</th>
#                         <td id="T_c2133_row1_col0" class="data row1 col0" >60</td>
#                         <td id="T_c2133_row1_col1" class="data row1 col1" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_c2133_level0_row2" class="row_heading level0 row2" >Std Deviation</th>
#                         <td id="T_c2133_row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_c2133_row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_c2133_level0_row3" class="row_heading level0 row3" >Min</th>
#                         <td id="T_c2133_row3_col0" class="data row3 col0" >19</td>
#                         <td id="T_c2133_row3_col1" class="data row3 col1" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_c2133_level0_row4" class="row_heading level0 row4" >Max</th>
#                         <td id="T_c2133_row4_col0" class="data row4 col0" >103</td>
#                         <td id="T_c2133_row4_col1" class="data row4 col1" >91</td>
#             </tr>
#             <tr>
#                         <th id="T_c2133_level0_row5" class="row_heading level0 row5" >IQR</th>
#                         <td id="T_c2133_row5_col0" class="data row5 col0" >18</td>
#                         <td id="T_c2133_row5_col1" class="data row5 col1" >21</td>
#             </tr>
#     </tbody></table>

# %%
plot_MI_vs_Healthy("Age", "Age")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Gender</h3>

# %%
explore_categorical_variable('Gender')
# Out:
#                Statistics  Values
# 0               Data Type  object
# 1                   Count    1319
# 2                    Mode    male
# 3  Num of Possible values       2

# %%
pie_plot(df, 'Gender', 'Gender', colors=['#4ccfbe','#875692'])

# %%
explore_categories('Gender',['male','female'])
# Out:
#    Gender  Count  Percentage
# 0    male    870       65.96
# 1  female    449       34.04

# %%
pie_with_target(df, 'Gender', 'Gender')

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Heart rate</h3>

# %%
explore_continuous_variable('Heart rate')
# Out:
# <style  type="text/css" >
# #T_0b664_row0_col0,#T_0b664_row0_col1,#T_0b664_row1_col0,#T_0b664_row1_col1,#T_0b664_row2_col0,#T_0b664_row2_col1,#T_0b664_row3_col0,#T_0b664_row3_col1,#T_0b664_row4_col0,#T_0b664_row4_col1,#T_0b664_row5_col0,#T_0b664_row5_col1,#T_0b664_row6_col0,#T_0b664_row6_col1,#T_0b664_row7_col0,#T_0b664_row7_col1,#T_0b664_row8_col0,#T_0b664_row8_col1,#T_0b664_row9_col0,#T_0b664_row9_col1,#T_0b664_row10_col0,#T_0b664_row10_col1,#T_0b664_row11_col0,#T_0b664_row11_col1,#T_0b664_row12_col0,#T_0b664_row12_col1,#T_0b664_row13_col0,#T_0b664_row13_col1,#T_0b664_row14_col0,#T_0b664_row14_col1,#T_0b664_row15_col0,#T_0b664_row15_col1,#T_0b664_row16_col0,#T_0b664_row16_col1,#T_0b664_row17_col0,#T_0b664_row17_col1,#T_0b664_row18_col0,#T_0b664_row18_col1,#T_0b664_row19_col0,#T_0b664_row19_col1,#T_0b664_row20_col0,#T_0b664_row20_col1,#T_0b664_row21_col0,#T_0b664_row21_col1,#T_0b664_row22_col0,#T_0b664_row22_col1{
#             text-align:  center;
#         }</style><table id="T_0b664_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Statistics</th>        <th class="col_heading level0 col1" >Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b664_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0b664_row0_col0" class="data row0 col0" >Feature</td>
#                         <td id="T_0b664_row0_col1" class="data row0 col1" >Heart rate</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0b664_row1_col0" class="data row1 col0" >Data Type</td>
#                         <td id="T_0b664_row1_col1" class="data row1 col1" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0b664_row2_col0" class="data row2 col0" >Minimum Value</td>
#                         <td id="T_0b664_row2_col1" class="data row2 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0b664_row3_col0" class="data row3 col0" >Maximum Value</td>
#                         <td id="T_0b664_row3_col1" class="data row3 col1" >1111</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0b664_row4_col0" class="data row4 col0" >Range</td>
#                         <td id="T_0b664_row4_col1" class="data row4 col1" >1091</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0b664_row5_col0" class="data row5 col0" >Mean</td>
#                         <td id="T_0b664_row5_col1" class="data row5 col1" >78</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0b664_row6_col0" class="data row6 col0" >Median</td>
#                         <td id="T_0b664_row6_col1" class="data row6 col1" >74</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0b664_row7_col0" class="data row7 col0" >Q3</td>
#                         <td id="T_0b664_row7_col1" class="data row7 col1" >85</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0b664_row8_col0" class="data row8 col0" >Q1</td>
#                         <td id="T_0b664_row8_col1" class="data row8 col1" >64</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0b664_row9_col0" class="data row9 col0" >IQR</td>
#                         <td id="T_0b664_row9_col1" class="data row9 col1" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_0b664_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#                         <td id="T_0b664_row10_col1" class="data row10 col1" >2.270000</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_0b664_row11_col0" class="data row11 col0" >Variance</td>
#                         <td id="T_0b664_row11_col1" class="data row11 col1" >2665.680000</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_0b664_row12_col0" class="data row12 col0" >Standard Deviation</td>
#                         <td id="T_0b664_row12_col1" class="data row12 col1" >51.630000</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_0b664_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#                         <td id="T_0b664_row13_col1" class="data row13 col1" >0.660000</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_0b664_row14_col0" class="data row14 col0" >Skewness</td>
#                         <td id="T_0b664_row14_col1" class="data row14 col1" >18.250000</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_0b664_row15_col0" class="data row15 col0" >10th Percentile</td>
#                         <td id="T_0b664_row15_col1" class="data row15 col1" >60</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_0b664_row16_col0" class="data row16 col0" >25th Percentile</td>
#                         <td id="T_0b664_row16_col1" class="data row16 col1" >64</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_0b664_row17_col0" class="data row17 col0" >50th Percentile</td>
#                         <td id="T_0b664_row17_col1" class="data row17 col1" >74</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_0b664_row18_col0" class="data row18 col0" >75th Percentile</td>
#                         <td id="T_0b664_row18_col1" class="data row18 col1" >85</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_0b664_row19_col0" class="data row19 col0" >90th Percentile</td>
#                         <td id="T_0b664_row19_col1" class="data row19 col1" >94</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_0b664_row20_col0" class="data row20 col0" >Number of Null Values</td>
#                         <td id="T_0b664_row20_col1" class="data row20 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0b664_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_0b664_row21_col0" class="data row21 col0" >Lower Band</td>
#                         <td id="T_0b664_row21_col1" class="data row21 col1" >32.500000</td>

# %%
plot_distribution(df, 'Heart rate', 'Heart rate')

# %%
compare_feature_statistics('Heart rate')
# Out:
# <style  type="text/css" >
# #T_d97b3_row0_col0,#T_d97b3_row0_col1,#T_d97b3_row1_col0,#T_d97b3_row1_col1,#T_d97b3_row2_col0,#T_d97b3_row2_col1,#T_d97b3_row3_col0,#T_d97b3_row3_col1,#T_d97b3_row4_col0,#T_d97b3_row4_col1,#T_d97b3_row5_col0,#T_d97b3_row5_col1{
#             text-align:  center;
#         }</style><table id="T_d97b3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d97b3_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_d97b3_row0_col0" class="data row0 col0" >78</td>
#                         <td id="T_d97b3_row0_col1" class="data row0 col1" >77</td>
#             </tr>
#             <tr>
#                         <th id="T_d97b3_level0_row1" class="row_heading level0 row1" >Median</th>
#                         <td id="T_d97b3_row1_col0" class="data row1 col0" >74</td>
#                         <td id="T_d97b3_row1_col1" class="data row1 col1" >75</td>
#             </tr>
#             <tr>
#                         <th id="T_d97b3_level0_row2" class="row_heading level0 row2" >Std Deviation</th>
#                         <td id="T_d97b3_row2_col0" class="data row2 col0" >53</td>
#                         <td id="T_d97b3_row2_col1" class="data row2 col1" >48</td>
#             </tr>
#             <tr>
#                         <th id="T_d97b3_level0_row3" class="row_heading level0 row3" >Min</th>
#                         <td id="T_d97b3_row3_col0" class="data row3 col0" >20</td>
#                         <td id="T_d97b3_row3_col1" class="data row3 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_d97b3_level0_row4" class="row_heading level0 row4" >Max</th>
#                         <td id="T_d97b3_row4_col0" class="data row4 col0" >1111</td>
#                         <td id="T_d97b3_row4_col1" class="data row4 col1" >1111</td>
#             </tr>
#             <tr>
#                         <th id="T_d97b3_level0_row5" class="row_heading level0 row5" >IQR</th>
#                         <td id="T_d97b3_row5_col0" class="data row5 col0" >21</td>
#                         <td id="T_d97b3_row5_col1" class="data row5 col1" >20</td>
#             </tr>
#     </tbody></table>

# %%
plot_MI_vs_Healthy("Heart rate", "Heart rate")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Systolic blood pressure</h3>

# %%
explore_continuous_variable('Systolic blood pressure')
# Out:
# <style  type="text/css" >
# #T_c8f38_row0_col0,#T_c8f38_row0_col1,#T_c8f38_row1_col0,#T_c8f38_row1_col1,#T_c8f38_row2_col0,#T_c8f38_row2_col1,#T_c8f38_row3_col0,#T_c8f38_row3_col1,#T_c8f38_row4_col0,#T_c8f38_row4_col1,#T_c8f38_row5_col0,#T_c8f38_row5_col1,#T_c8f38_row6_col0,#T_c8f38_row6_col1,#T_c8f38_row7_col0,#T_c8f38_row7_col1,#T_c8f38_row8_col0,#T_c8f38_row8_col1,#T_c8f38_row9_col0,#T_c8f38_row9_col1,#T_c8f38_row10_col0,#T_c8f38_row10_col1,#T_c8f38_row11_col0,#T_c8f38_row11_col1,#T_c8f38_row12_col0,#T_c8f38_row12_col1,#T_c8f38_row13_col0,#T_c8f38_row13_col1,#T_c8f38_row14_col0,#T_c8f38_row14_col1,#T_c8f38_row15_col0,#T_c8f38_row15_col1,#T_c8f38_row16_col0,#T_c8f38_row16_col1,#T_c8f38_row17_col0,#T_c8f38_row17_col1,#T_c8f38_row18_col0,#T_c8f38_row18_col1,#T_c8f38_row19_col0,#T_c8f38_row19_col1,#T_c8f38_row20_col0,#T_c8f38_row20_col1,#T_c8f38_row21_col0,#T_c8f38_row21_col1,#T_c8f38_row22_col0,#T_c8f38_row22_col1{
#             text-align:  center;
#         }</style><table id="T_c8f38_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Statistics</th>        <th class="col_heading level0 col1" >Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c8f38_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c8f38_row0_col0" class="data row0 col0" >Feature</td>
#                         <td id="T_c8f38_row0_col1" class="data row0 col1" >Systolic blood pressure</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c8f38_row1_col0" class="data row1 col0" >Data Type</td>
#                         <td id="T_c8f38_row1_col1" class="data row1 col1" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c8f38_row2_col0" class="data row2 col0" >Minimum Value</td>
#                         <td id="T_c8f38_row2_col1" class="data row2 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c8f38_row3_col0" class="data row3 col0" >Maximum Value</td>
#                         <td id="T_c8f38_row3_col1" class="data row3 col1" >223</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c8f38_row4_col0" class="data row4 col0" >Range</td>
#                         <td id="T_c8f38_row4_col1" class="data row4 col1" >181</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c8f38_row5_col0" class="data row5 col0" >Mean</td>
#                         <td id="T_c8f38_row5_col1" class="data row5 col1" >127</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c8f38_row6_col0" class="data row6 col0" >Median</td>
#                         <td id="T_c8f38_row6_col1" class="data row6 col1" >124</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c8f38_row7_col0" class="data row7 col0" >Q3</td>
#                         <td id="T_c8f38_row7_col1" class="data row7 col1" >143</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c8f38_row8_col0" class="data row8 col0" >Q1</td>
#                         <td id="T_c8f38_row8_col1" class="data row8 col1" >110</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c8f38_row9_col0" class="data row9 col0" >IQR</td>
#                         <td id="T_c8f38_row9_col1" class="data row9 col1" >33</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_c8f38_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#                         <td id="T_c8f38_row10_col1" class="data row10 col1" >2.430000</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_c8f38_row11_col0" class="data row11 col0" >Variance</td>
#                         <td id="T_c8f38_row11_col1" class="data row11 col1" >682.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_c8f38_row12_col0" class="data row12 col0" >Standard Deviation</td>
#                         <td id="T_c8f38_row12_col1" class="data row12 col1" >26.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_c8f38_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#                         <td id="T_c8f38_row13_col1" class="data row13 col1" >0.210000</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_c8f38_row14_col0" class="data row14 col0" >Skewness</td>
#                         <td id="T_c8f38_row14_col1" class="data row14 col1" >0.690000</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_c8f38_row15_col0" class="data row15 col0" >10th Percentile</td>
#                         <td id="T_c8f38_row15_col1" class="data row15 col1" >96</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_c8f38_row16_col0" class="data row16 col0" >25th Percentile</td>
#                         <td id="T_c8f38_row16_col1" class="data row16 col1" >110</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_c8f38_row17_col0" class="data row17 col0" >50th Percentile</td>
#                         <td id="T_c8f38_row17_col1" class="data row17 col1" >124</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_c8f38_row18_col0" class="data row18 col0" >75th Percentile</td>
#                         <td id="T_c8f38_row18_col1" class="data row18 col1" >143</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_c8f38_row19_col0" class="data row19 col0" >90th Percentile</td>
#                         <td id="T_c8f38_row19_col1" class="data row19 col1" >160</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_c8f38_row20_col0" class="data row20 col0" >Number of Null Values</td>
#                         <td id="T_c8f38_row20_col1" class="data row20 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c8f38_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_c8f38_row21_col0" class="data row21 col0" >Lower Band</td>
#                         <td id="T_c8f38_row21_col1" class="data row21 col1" >60.5000

# %%
plot_distribution(df, 'Systolic blood pressure', 'Systolic blood pressure')

# %%
compare_feature_statistics('Systolic blood pressure')
# Out:
# <style  type="text/css" >
# #T_41f18_row0_col0,#T_41f18_row0_col1,#T_41f18_row1_col0,#T_41f18_row1_col1,#T_41f18_row2_col0,#T_41f18_row2_col1,#T_41f18_row3_col0,#T_41f18_row3_col1,#T_41f18_row4_col0,#T_41f18_row4_col1,#T_41f18_row5_col0,#T_41f18_row5_col1{
#             text-align:  center;
#         }</style><table id="T_41f18_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41f18_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_41f18_row0_col0" class="data row0 col0" >126</td>
#                         <td id="T_41f18_row0_col1" class="data row0 col1" >127</td>
#             </tr>
#             <tr>
#                         <th id="T_41f18_level0_row1" class="row_heading level0 row1" >Median</th>
#                         <td id="T_41f18_row1_col0" class="data row1 col0" >122</td>
#                         <td id="T_41f18_row1_col1" class="data row1 col1" >125</td>
#             </tr>
#             <tr>
#                         <th id="T_41f18_level0_row2" class="row_heading level0 row2" >Std Deviation</th>
#                         <td id="T_41f18_row2_col0" class="data row2 col0" >25</td>
#                         <td id="T_41f18_row2_col1" class="data row2 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_41f18_level0_row3" class="row_heading level0 row3" >Min</th>
#                         <td id="T_41f18_row3_col0" class="data row3 col0" >65</td>
#                         <td id="T_41f18_row3_col1" class="data row3 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_41f18_level0_row4" class="row_heading level0 row4" >Max</th>
#                         <td id="T_41f18_row4_col0" class="data row4 col0" >223</td>
#                         <td id="T_41f18_row4_col1" class="data row4 col1" >223</td>
#             </tr>
#             <tr>
#                         <th id="T_41f18_level0_row5" class="row_heading level0 row5" >IQR</th>
#                         <td id="T_41f18_row5_col0" class="data row5 col0" >30</td>
#                         <td id="T_41f18_row5_col1" class="data row5 col1" >37</td>
#             </tr>
#     </tbody></table>

# %%
plot_MI_vs_Healthy("Systolic blood pressure", "Systolic blood pressure")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Diastolic blood pressure</h3>

# %%
explore_continuous_variable('Diastolic blood pressure')
# Out:
# <style  type="text/css" >
# #T_b7aa5_row0_col0,#T_b7aa5_row0_col1,#T_b7aa5_row1_col0,#T_b7aa5_row1_col1,#T_b7aa5_row2_col0,#T_b7aa5_row2_col1,#T_b7aa5_row3_col0,#T_b7aa5_row3_col1,#T_b7aa5_row4_col0,#T_b7aa5_row4_col1,#T_b7aa5_row5_col0,#T_b7aa5_row5_col1,#T_b7aa5_row6_col0,#T_b7aa5_row6_col1,#T_b7aa5_row7_col0,#T_b7aa5_row7_col1,#T_b7aa5_row8_col0,#T_b7aa5_row8_col1,#T_b7aa5_row9_col0,#T_b7aa5_row9_col1,#T_b7aa5_row10_col0,#T_b7aa5_row10_col1,#T_b7aa5_row11_col0,#T_b7aa5_row11_col1,#T_b7aa5_row12_col0,#T_b7aa5_row12_col1,#T_b7aa5_row13_col0,#T_b7aa5_row13_col1,#T_b7aa5_row14_col0,#T_b7aa5_row14_col1,#T_b7aa5_row15_col0,#T_b7aa5_row15_col1,#T_b7aa5_row16_col0,#T_b7aa5_row16_col1,#T_b7aa5_row17_col0,#T_b7aa5_row17_col1,#T_b7aa5_row18_col0,#T_b7aa5_row18_col1,#T_b7aa5_row19_col0,#T_b7aa5_row19_col1,#T_b7aa5_row20_col0,#T_b7aa5_row20_col1,#T_b7aa5_row21_col0,#T_b7aa5_row21_col1,#T_b7aa5_row22_col0,#T_b7aa5_row22_col1{
#             text-align:  center;
#         }</style><table id="T_b7aa5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Statistics</th>        <th class="col_heading level0 col1" >Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7aa5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b7aa5_row0_col0" class="data row0 col0" >Feature</td>
#                         <td id="T_b7aa5_row0_col1" class="data row0 col1" >Diastolic blood pressure</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b7aa5_row1_col0" class="data row1 col0" >Data Type</td>
#                         <td id="T_b7aa5_row1_col1" class="data row1 col1" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b7aa5_row2_col0" class="data row2 col0" >Minimum Value</td>
#                         <td id="T_b7aa5_row2_col1" class="data row2 col1" >38</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b7aa5_row3_col0" class="data row3 col0" >Maximum Value</td>
#                         <td id="T_b7aa5_row3_col1" class="data row3 col1" >154</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b7aa5_row4_col0" class="data row4 col0" >Range</td>
#                         <td id="T_b7aa5_row4_col1" class="data row4 col1" >116</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b7aa5_row5_col0" class="data row5 col0" >Mean</td>
#                         <td id="T_b7aa5_row5_col1" class="data row5 col1" >72</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b7aa5_row6_col0" class="data row6 col0" >Median</td>
#                         <td id="T_b7aa5_row6_col1" class="data row6 col1" >72</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b7aa5_row7_col0" class="data row7 col0" >Q3</td>
#                         <td id="T_b7aa5_row7_col1" class="data row7 col1" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b7aa5_row8_col0" class="data row8 col0" >Q1</td>
#                         <td id="T_b7aa5_row8_col1" class="data row8 col1" >62</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_b7aa5_row9_col0" class="data row9 col0" >IQR</td>
#                         <td id="T_b7aa5_row9_col1" class="data row9 col1" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_b7aa5_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#                         <td id="T_b7aa5_row10_col1" class="data row10 col1" >0.910000</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_b7aa5_row11_col0" class="data row11 col0" >Variance</td>
#                         <td id="T_b7aa5_row11_col1" class="data row11 col1" >196.950000</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_b7aa5_row12_col0" class="data row12 col0" >Standard Deviation</td>
#                         <td id="T_b7aa5_row12_col1" class="data row12 col1" >14.030000</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_b7aa5_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#                         <td id="T_b7aa5_row13_col1" class="data row13 col1" >0.190000</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_b7aa5_row14_col0" class="data row14 col0" >Skewness</td>
#                         <td id="T_b7aa5_row14_col1" class="data row14 col1" >0.490000</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_b7aa5_row15_col0" class="data row15 col0" >10th Percentile</td>
#                         <td id="T_b7aa5_row15_col1" class="data row15 col1" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_b7aa5_row16_col0" class="data row16 col0" >25th Percentile</td>
#                         <td id="T_b7aa5_row16_col1" class="data row16 col1" >62</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_b7aa5_row17_col0" class="data row17 col0" >50th Percentile</td>
#                         <td id="T_b7aa5_row17_col1" class="data row17 col1" >72</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_b7aa5_row18_col0" class="data row18 col0" >75th Percentile</td>
#                         <td id="T_b7aa5_row18_col1" class="data row18 col1" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_b7aa5_row19_col0" class="data row19 col0" >90th Percentile</td>
#                         <td id="T_b7aa5_row19_col1" class="data row19 col1" >90</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_b7aa5_row20_col0" class="data row20 col0" >Number of Null Values</td>
#                         <td id="T_b7aa5_row20_col1" class="data row20 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b7aa5_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_b7aa5_row21_col0" class="data row21 col0" >Lower Band</td>
#                         <td id="T_b7aa5_row21_col1" class="data row21 col1" >33.500000</td>

# %%
plot_distribution(df, 'Diastolic blood pressure', 'Diastolic blood pressure')

# %%
compare_feature_statistics('Diastolic blood pressure')
# Out:
# <style  type="text/css" >
# #T_7abbd_row0_col0,#T_7abbd_row0_col1,#T_7abbd_row1_col0,#T_7abbd_row1_col1,#T_7abbd_row2_col0,#T_7abbd_row2_col1,#T_7abbd_row3_col0,#T_7abbd_row3_col1,#T_7abbd_row4_col0,#T_7abbd_row4_col1,#T_7abbd_row5_col0,#T_7abbd_row5_col1{
#             text-align:  center;
#         }</style><table id="T_7abbd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7abbd_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_7abbd_row0_col0" class="data row0 col0" >72</td>
#                         <td id="T_7abbd_row0_col1" class="data row0 col1" >72</td>
#             </tr>
#             <tr>
#                         <th id="T_7abbd_level0_row1" class="row_heading level0 row1" >Median</th>
#                         <td id="T_7abbd_row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_7abbd_row1_col1" class="data row1 col1" >72</td>
#             </tr>
#             <tr>
#                         <th id="T_7abbd_level0_row2" class="row_heading level0 row2" >Std Deviation</th>
#                         <td id="T_7abbd_row2_col0" class="data row2 col0" >13</td>
#                         <td id="T_7abbd_row2_col1" class="data row2 col1" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_7abbd_level0_row3" class="row_heading level0 row3" >Min</th>
#                         <td id="T_7abbd_row3_col0" class="data row3 col0" >38</td>
#                         <td id="T_7abbd_row3_col1" class="data row3 col1" >40</td>
#             </tr>
#             <tr>
#                         <th id="T_7abbd_level0_row4" class="row_heading level0 row4" >Max</th>
#                         <td id="T_7abbd_row4_col0" class="data row4 col0" >154</td>
#                         <td id="T_7abbd_row4_col1" class="data row4 col1" >128</td>
#             </tr>
#             <tr>
#                         <th id="T_7abbd_level0_row5" class="row_heading level0 row5" >IQR</th>
#                         <td id="T_7abbd_row5_col0" class="data row5 col0" >18</td>
#                         <td id="T_7abbd_row5_col1" class="data row5 col1" >21</td>
#             </tr>
#     </tbody></table>

# %%
plot_MI_vs_Healthy("Diastolic blood pressure", "Diastolic blood pressure")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Blood sugar</h3>

# %%
explore_continuous_variable('Blood sugar')
# Out:
# <style  type="text/css" >
# #T_3e6e5_row0_col0,#T_3e6e5_row0_col1,#T_3e6e5_row1_col0,#T_3e6e5_row1_col1,#T_3e6e5_row2_col0,#T_3e6e5_row2_col1,#T_3e6e5_row3_col0,#T_3e6e5_row3_col1,#T_3e6e5_row4_col0,#T_3e6e5_row4_col1,#T_3e6e5_row5_col0,#T_3e6e5_row5_col1,#T_3e6e5_row6_col0,#T_3e6e5_row6_col1,#T_3e6e5_row7_col0,#T_3e6e5_row7_col1,#T_3e6e5_row8_col0,#T_3e6e5_row8_col1,#T_3e6e5_row9_col0,#T_3e6e5_row9_col1,#T_3e6e5_row10_col0,#T_3e6e5_row10_col1,#T_3e6e5_row11_col0,#T_3e6e5_row11_col1,#T_3e6e5_row12_col0,#T_3e6e5_row12_col1,#T_3e6e5_row13_col0,#T_3e6e5_row13_col1,#T_3e6e5_row14_col0,#T_3e6e5_row14_col1,#T_3e6e5_row15_col0,#T_3e6e5_row15_col1,#T_3e6e5_row16_col0,#T_3e6e5_row16_col1,#T_3e6e5_row17_col0,#T_3e6e5_row17_col1,#T_3e6e5_row18_col0,#T_3e6e5_row18_col1,#T_3e6e5_row19_col0,#T_3e6e5_row19_col1,#T_3e6e5_row20_col0,#T_3e6e5_row20_col1,#T_3e6e5_row21_col0,#T_3e6e5_row21_col1,#T_3e6e5_row22_col0,#T_3e6e5_row22_col1{
#             text-align:  center;
#         }</style><table id="T_3e6e5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Statistics</th>        <th class="col_heading level0 col1" >Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3e6e5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3e6e5_row0_col0" class="data row0 col0" >Feature</td>
#                         <td id="T_3e6e5_row0_col1" class="data row0 col1" >Blood sugar</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3e6e5_row1_col0" class="data row1 col0" >Data Type</td>
#                         <td id="T_3e6e5_row1_col1" class="data row1 col1" >float64</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3e6e5_row2_col0" class="data row2 col0" >Minimum Value</td>
#                         <td id="T_3e6e5_row2_col1" class="data row2 col1" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3e6e5_row3_col0" class="data row3 col0" >Maximum Value</td>
#                         <td id="T_3e6e5_row3_col1" class="data row3 col1" >541</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3e6e5_row4_col0" class="data row4 col0" >Range</td>
#                         <td id="T_3e6e5_row4_col1" class="data row4 col1" >506</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3e6e5_row5_col0" class="data row5 col0" >Mean</td>
#                         <td id="T_3e6e5_row5_col1" class="data row5 col1" >147</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3e6e5_row6_col0" class="data row6 col0" >Median</td>
#                         <td id="T_3e6e5_row6_col1" class="data row6 col1" >116</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3e6e5_row7_col0" class="data row7 col0" >Q3</td>
#                         <td id="T_3e6e5_row7_col1" class="data row7 col1" >169</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3e6e5_row8_col0" class="data row8 col0" >Q1</td>
#                         <td id="T_3e6e5_row8_col1" class="data row8 col1" >98</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3e6e5_row9_col0" class="data row9 col0" >IQR</td>
#                         <td id="T_3e6e5_row9_col1" class="data row9 col1" >71</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_3e6e5_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#                         <td id="T_3e6e5_row10_col1" class="data row10 col1" >7.130000</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_3e6e5_row11_col0" class="data row11 col0" >Variance</td>
#                         <td id="T_3e6e5_row11_col1" class="data row11 col1" >5613.460000</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_3e6e5_row12_col0" class="data row12 col0" >Standard Deviation</td>
#                         <td id="T_3e6e5_row12_col1" class="data row12 col1" >74.920000</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_3e6e5_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#                         <td id="T_3e6e5_row13_col1" class="data row13 col1" >0.510000</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_3e6e5_row14_col0" class="data row14 col0" >Skewness</td>
#                         <td id="T_3e6e5_row14_col1" class="data row14 col1" >1.930000</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_3e6e5_row15_col0" class="data row15 col0" >10th Percentile</td>
#                         <td id="T_3e6e5_row15_col1" class="data row15 col1" >88</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_3e6e5_row16_col0" class="data row16 col0" >25th Percentile</td>
#                         <td id="T_3e6e5_row16_col1" class="data row16 col1" >98</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_3e6e5_row17_col0" class="data row17 col0" >50th Percentile</td>
#                         <td id="T_3e6e5_row17_col1" class="data row17 col1" >116</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_3e6e5_row18_col0" class="data row18 col0" >75th Percentile</td>
#                         <td id="T_3e6e5_row18_col1" class="data row18 col1" >169</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_3e6e5_row19_col0" class="data row19 col0" >90th Percentile</td>
#                         <td id="T_3e6e5_row19_col1" class="data row19 col1" >245</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_3e6e5_row20_col0" class="data row20 col0" >Number of Null Values</td>
#                         <td id="T_3e6e5_row20_col1" class="data row20 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_3e6e5_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_3e6e5_row21_col0" class="data row21 col0" >Lower Band</td>
#                         <td id="T_3e6e5_row21_col1" class="data row21 col1" >-8.500000</td>

# %%
plot_distribution(df, 'Blood sugar', 'Blood sugar')

# %%
compare_feature_statistics('Blood sugar')
# Out:
# <style  type="text/css" >
# #T_e67c0_row0_col0,#T_e67c0_row0_col1,#T_e67c0_row1_col0,#T_e67c0_row1_col1,#T_e67c0_row2_col0,#T_e67c0_row2_col1,#T_e67c0_row3_col0,#T_e67c0_row3_col1,#T_e67c0_row4_col0,#T_e67c0_row4_col1,#T_e67c0_row5_col0,#T_e67c0_row5_col1{
#             text-align:  center;
#         }</style><table id="T_e67c0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e67c0_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_e67c0_row0_col0" class="data row0 col0" >144</td>
#                         <td id="T_e67c0_row0_col1" class="data row0 col1" >149</td>
#             </tr>
#             <tr>
#                         <th id="T_e67c0_level0_row1" class="row_heading level0 row1" >Median</th>
#                         <td id="T_e67c0_row1_col0" class="data row1 col0" >116</td>
#                         <td id="T_e67c0_row1_col1" class="data row1 col1" >117</td>
#             </tr>
#             <tr>
#                         <th id="T_e67c0_level0_row2" class="row_heading level0 row2" >Std Deviation</th>
#                         <td id="T_e67c0_row2_col0" class="data row2 col0" >72</td>
#                         <td id="T_e67c0_row2_col1" class="data row2 col1" >78</td>
#             </tr>
#             <tr>
#                         <th id="T_e67c0_level0_row3" class="row_heading level0 row3" >Min</th>
#                         <td id="T_e67c0_row3_col0" class="data row3 col0" >35</td>
#                         <td id="T_e67c0_row3_col1" class="data row3 col1" >60</td>
#             </tr>
#             <tr>
#                         <th id="T_e67c0_level0_row4" class="row_heading level0 row4" >Max</th>
#                         <td id="T_e67c0_row4_col0" class="data row4 col0" >541</td>
#                         <td id="T_e67c0_row4_col1" class="data row4 col1" >541</td>
#             </tr>
#             <tr>
#                         <th id="T_e67c0_level0_row5" class="row_heading level0 row5" >IQR</th>
#                         <td id="T_e67c0_row5_col0" class="data row5 col0" >68</td>
#                         <td id="T_e67c0_row5_col1" class="data row5 col1" >86</td>
#             </tr>
#     </tbody></table>

# %%
plot_MI_vs_Healthy("Blood sugar", "Blood sugar")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">CK-MB</h3>

# %%
explore_continuous_variable('CK-MB')
# Out:
# <style  type="text/css" >
# #T_86ff4_row0_col0,#T_86ff4_row0_col1,#T_86ff4_row1_col0,#T_86ff4_row1_col1,#T_86ff4_row2_col0,#T_86ff4_row2_col1,#T_86ff4_row3_col0,#T_86ff4_row3_col1,#T_86ff4_row4_col0,#T_86ff4_row4_col1,#T_86ff4_row5_col0,#T_86ff4_row5_col1,#T_86ff4_row6_col0,#T_86ff4_row6_col1,#T_86ff4_row7_col0,#T_86ff4_row7_col1,#T_86ff4_row8_col0,#T_86ff4_row8_col1,#T_86ff4_row9_col0,#T_86ff4_row9_col1,#T_86ff4_row10_col0,#T_86ff4_row10_col1,#T_86ff4_row11_col0,#T_86ff4_row11_col1,#T_86ff4_row12_col0,#T_86ff4_row12_col1,#T_86ff4_row13_col0,#T_86ff4_row13_col1,#T_86ff4_row14_col0,#T_86ff4_row14_col1,#T_86ff4_row15_col0,#T_86ff4_row15_col1,#T_86ff4_row16_col0,#T_86ff4_row16_col1,#T_86ff4_row17_col0,#T_86ff4_row17_col1,#T_86ff4_row18_col0,#T_86ff4_row18_col1,#T_86ff4_row19_col0,#T_86ff4_row19_col1,#T_86ff4_row20_col0,#T_86ff4_row20_col1,#T_86ff4_row21_col0,#T_86ff4_row21_col1,#T_86ff4_row22_col0,#T_86ff4_row22_col1{
#             text-align:  center;
#         }</style><table id="T_86ff4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Statistics</th>        <th class="col_heading level0 col1" >Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86ff4_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_86ff4_row0_col0" class="data row0 col0" >Feature</td>
#                         <td id="T_86ff4_row0_col1" class="data row0 col1" >CK-MB</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_86ff4_row1_col0" class="data row1 col0" >Data Type</td>
#                         <td id="T_86ff4_row1_col1" class="data row1 col1" >float64</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_86ff4_row2_col0" class="data row2 col0" >Minimum Value</td>
#                         <td id="T_86ff4_row2_col1" class="data row2 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_86ff4_row3_col0" class="data row3 col0" >Maximum Value</td>
#                         <td id="T_86ff4_row3_col1" class="data row3 col1" >300</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_86ff4_row4_col0" class="data row4 col0" >Range</td>
#                         <td id="T_86ff4_row4_col1" class="data row4 col1" >300</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_86ff4_row5_col0" class="data row5 col0" >Mean</td>
#                         <td id="T_86ff4_row5_col1" class="data row5 col1" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_86ff4_row6_col0" class="data row6 col0" >Median</td>
#                         <td id="T_86ff4_row6_col1" class="data row6 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_86ff4_row7_col0" class="data row7 col0" >Q3</td>
#                         <td id="T_86ff4_row7_col1" class="data row7 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_86ff4_row8_col0" class="data row8 col0" >Q1</td>
#                         <td id="T_86ff4_row8_col1" class="data row8 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_86ff4_row9_col0" class="data row9 col0" >IQR</td>
#                         <td id="T_86ff4_row9_col1" class="data row9 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_86ff4_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#                         <td id="T_86ff4_row10_col1" class="data row10 col1" >16.380000</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_86ff4_row11_col0" class="data row11 col0" >Variance</td>
#                         <td id="T_86ff4_row11_col1" class="data row11 col1" >2146.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_86ff4_row12_col0" class="data row12 col0" >Standard Deviation</td>
#                         <td id="T_86ff4_row12_col1" class="data row12 col1" >46.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_86ff4_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#                         <td id="T_86ff4_row13_col1" class="data row13 col1" >3.090000</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_86ff4_row14_col0" class="data row14 col0" >Skewness</td>
#                         <td id="T_86ff4_row14_col1" class="data row14 col1" >4.980000</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_86ff4_row15_col0" class="data row15 col0" >10th Percentile</td>
#                         <td id="T_86ff4_row15_col1" class="data row15 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_86ff4_row16_col0" class="data row16 col0" >25th Percentile</td>
#                         <td id="T_86ff4_row16_col1" class="data row16 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_86ff4_row17_col0" class="data row17 col0" >50th Percentile</td>
#                         <td id="T_86ff4_row17_col1" class="data row17 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_86ff4_row18_col0" class="data row18 col0" >75th Percentile</td>
#                         <td id="T_86ff4_row18_col1" class="data row18 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_86ff4_row19_col0" class="data row19 col0" >90th Percentile</td>
#                         <td id="T_86ff4_row19_col1" class="data row19 col1" >25</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_86ff4_row20_col0" class="data row20 col0" >Number of Null Values</td>
#                         <td id="T_86ff4_row20_col1" class="data row20 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_86ff4_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_86ff4_row21_col0" class="data row21 col0" >Lower Band</td>
#                         <td id="T_86ff4_row21_col1" class="data row21 col1" >-5.000000</td>
#             </tr>

# %%
plot_distribution(df, 'CK-MB', 'CK-MB')

# %%
compare_feature_statistics('CK-MB')
# Out:
# <style  type="text/css" >
# #T_9e5b3_row0_col0,#T_9e5b3_row0_col1,#T_9e5b3_row1_col0,#T_9e5b3_row1_col1,#T_9e5b3_row2_col0,#T_9e5b3_row2_col1,#T_9e5b3_row3_col0,#T_9e5b3_row3_col1,#T_9e5b3_row4_col0,#T_9e5b3_row4_col1,#T_9e5b3_row5_col0,#T_9e5b3_row5_col1{
#             text-align:  center;
#         }</style><table id="T_9e5b3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e5b3_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_9e5b3_row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_9e5b3_row0_col1" class="data row0 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_9e5b3_level0_row1" class="row_heading level0 row1" >Median</th>
#                         <td id="T_9e5b3_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_9e5b3_row1_col1" class="data row1 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_9e5b3_level0_row2" class="row_heading level0 row2" >Std Deviation</th>
#                         <td id="T_9e5b3_row2_col0" class="data row2 col0" >57</td>
#                         <td id="T_9e5b3_row2_col1" class="data row2 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_9e5b3_level0_row3" class="row_heading level0 row3" >Min</th>
#                         <td id="T_9e5b3_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_9e5b3_row3_col1" class="data row3 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_9e5b3_level0_row4" class="row_heading level0 row4" >Max</th>
#                         <td id="T_9e5b3_row4_col0" class="data row4 col0" >300</td>
#                         <td id="T_9e5b3_row4_col1" class="data row4 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_9e5b3_level0_row5" class="row_heading level0 row5" >IQR</th>
#                         <td id="T_9e5b3_row5_col0" class="data row5 col0" >10</td>
#                         <td id="T_9e5b3_row5_col1" class="data row5 col1" >1</td>
#             </tr>
#     </tbody></table>

# %%
plot_MI_vs_Healthy("CK-MB", "CK-MB")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Troponin</h3>

# %%
explore_continuous_variable('Troponin')
# Out:
# <ipython-input-257-6fd738205731>:19: RuntimeWarning: divide by zero encountered in double_scalars
#   coefficient_of_variation = round(np.sqrt(variance) / mean, 2)
# <style  type="text/css" >
# #T_cd16a_row0_col0,#T_cd16a_row0_col1,#T_cd16a_row1_col0,#T_cd16a_row1_col1,#T_cd16a_row2_col0,#T_cd16a_row2_col1,#T_cd16a_row3_col0,#T_cd16a_row3_col1,#T_cd16a_row4_col0,#T_cd16a_row4_col1,#T_cd16a_row5_col0,#T_cd16a_row5_col1,#T_cd16a_row6_col0,#T_cd16a_row6_col1,#T_cd16a_row7_col0,#T_cd16a_row7_col1,#T_cd16a_row8_col0,#T_cd16a_row8_col1,#T_cd16a_row9_col0,#T_cd16a_row9_col1,#T_cd16a_row10_col0,#T_cd16a_row10_col1,#T_cd16a_row11_col0,#T_cd16a_row11_col1,#T_cd16a_row12_col0,#T_cd16a_row12_col1,#T_cd16a_row13_col0,#T_cd16a_row13_col1,#T_cd16a_row14_col0,#T_cd16a_row14_col1,#T_cd16a_row15_col0,#T_cd16a_row15_col1,#T_cd16a_row16_col0,#T_cd16a_row16_col1,#T_cd16a_row17_col0,#T_cd16a_row17_col1,#T_cd16a_row18_col0,#T_cd16a_row18_col1,#T_cd16a_row19_col0,#T_cd16a_row19_col1,#T_cd16a_row20_col0,#T_cd16a_row20_col1,#T_cd16a_row21_col0,#T_cd16a_row21_col1,#T_cd16a_row22_col0,#T_cd16a_row22_col1{
#             text-align:  center;
#         }</style><table id="T_cd16a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Statistics</th>        <th class="col_heading level0 col1" >Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cd16a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cd16a_row0_col0" class="data row0 col0" >Feature</td>
#                         <td id="T_cd16a_row0_col1" class="data row0 col1" >Troponin</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cd16a_row1_col0" class="data row1 col0" >Data Type</td>
#                         <td id="T_cd16a_row1_col1" class="data row1 col1" >float64</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cd16a_row2_col0" class="data row2 col0" >Minimum Value</td>
#                         <td id="T_cd16a_row2_col1" class="data row2 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cd16a_row3_col0" class="data row3 col0" >Maximum Value</td>
#                         <td id="T_cd16a_row3_col1" class="data row3 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cd16a_row4_col0" class="data row4 col0" >Range</td>
#                         <td id="T_cd16a_row4_col1" class="data row4 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_cd16a_row5_col0" class="data row5 col0" >Mean</td>
#                         <td id="T_cd16a_row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_cd16a_row6_col0" class="data row6 col0" >Median</td>
#                         <td id="T_cd16a_row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_cd16a_row7_col0" class="data row7 col0" >Q3</td>
#                         <td id="T_cd16a_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_cd16a_row8_col0" class="data row8 col0" >Q1</td>
#                         <td id="T_cd16a_row8_col1" class="data row8 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_cd16a_row9_col0" class="data row9 col0" >IQR</td>
#                         <td id="T_cd16a_row9_col1" class="data row9 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_cd16a_row10_col0" class="data row10 col0" >Outliers Percentage</td>
#                         <td id="T_cd16a_row10_col1" class="data row10 col1" >100.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_cd16a_row11_col0" class="data row11 col0" >Variance</td>
#                         <td id="T_cd16a_row11_col1" class="data row11 col1" >1.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_cd16a_row12_col0" class="data row12 col0" >Standard Deviation</td>
#                         <td id="T_cd16a_row12_col1" class="data row12 col1" >1.150000</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_cd16a_row13_col0" class="data row13 col0" >Coefficient of Variation</td>
#                         <td id="T_cd16a_row13_col1" class="data row13 col1" >inf</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_cd16a_row14_col0" class="data row14 col0" >Skewness</td>
#                         <td id="T_cd16a_row14_col1" class="data row14 col1" >5.800000</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_cd16a_row15_col0" class="data row15 col0" >10th Percentile</td>
#                         <td id="T_cd16a_row15_col1" class="data row15 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_cd16a_row16_col0" class="data row16 col0" >25th Percentile</td>
#                         <td id="T_cd16a_row16_col1" class="data row16 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_cd16a_row17_col0" class="data row17 col0" >50th Percentile</td>
#                         <td id="T_cd16a_row17_col1" class="data row17 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_cd16a_row18_col0" class="data row18 col0" >75th Percentile</td>
#                         <td id="T_cd16a_row18_col1" class="data row18 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_cd16a_row19_col0" class="data row19 col0" >90th Percentile</td>
#                         <td id="T_cd16a_row19_col1" class="data row19 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_cd16a_row20_col0" class="data row20 col0" >Number of Null Values</td>
#                         <td id="T_cd16a_row20_col1" class="data row20 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cd16a_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_cd16a_row21_col0" class="data row21 col0" >Lower Band</td>
#                         <td id="T_cd16a_row21_col1" class="data row21 col1" >0.000000</td>
#             </tr>
#             <tr

# %%
plot_distribution(df, 'Troponin', 'Troponin')

# %%
compare_feature_statistics('Troponin')
# Out:
# <style  type="text/css" >
# #T_5f6ea_row0_col0,#T_5f6ea_row0_col1,#T_5f6ea_row1_col0,#T_5f6ea_row1_col1,#T_5f6ea_row2_col0,#T_5f6ea_row2_col1,#T_5f6ea_row3_col0,#T_5f6ea_row3_col1,#T_5f6ea_row4_col0,#T_5f6ea_row4_col1,#T_5f6ea_row5_col0,#T_5f6ea_row5_col1{
#             text-align:  center;
#         }</style><table id="T_5f6ea_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f6ea_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_5f6ea_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_5f6ea_row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5f6ea_level0_row1" class="row_heading level0 row1" >Median</th>
#                         <td id="T_5f6ea_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_5f6ea_row1_col1" class="data row1 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5f6ea_level0_row2" class="row_heading level0 row2" >Std Deviation</th>
#                         <td id="T_5f6ea_row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_5f6ea_row2_col1" class="data row2 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5f6ea_level0_row3" class="row_heading level0 row3" >Min</th>
#                         <td id="T_5f6ea_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_5f6ea_row3_col1" class="data row3 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5f6ea_level0_row4" class="row_heading level0 row4" >Max</th>
#                         <td id="T_5f6ea_row4_col0" class="data row4 col0" >10</td>
#                         <td id="T_5f6ea_row4_col1" class="data row4 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_5f6ea_level0_row5" class="row_heading level0 row5" >IQR</th>
#                         <td id="T_5f6ea_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_5f6ea_row5_col1" class="data row5 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
plot_MI_vs_Healthy("Troponin", "Troponin")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Target</h3>

# %%
explore_categorical_variable('MI')
# Out:
#                Statistics  Values
# 0               Data Type  object
# 1                   Count    1319
# 2                    Mode      MI
# 3  Num of Possible values       2

# %%
pie_plot(df, 'MI', 'Target', colors=['#875692','#4ccfbe'])

# %%
explore_categories('MI',[1,0])
# Out:
#         MI  Count  Percentage
# 0       MI    810       61.41
# 1  Healthy    509       38.59

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Multivariate Analysis</h3>

# %% [markdown]
# The primary goal of this multivariate analysis is to gain deeper insights into the complex interplay of factors contributing to not only the risk of coronary heart disease, but also other risk factors and diseases. By examining the relationships between various features in the dataset, we aim to identify key risk factors and potential recommendations for cardiovascular health.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#e7fbf8;font-family:newtimeroman;font-size:210%;text-align:center;border-radius: 15px 50px;">Defining Function</h3>

# %%
label_mapping = {0: 'Healthy', 1: 'MI'}
def dual_scatter_plot(df, x_feature, y_feature, hue_feature='MI', palette={0: '#4ccfbe', 1: '#875692'}, title1='Scatter Plot', title2='Scatter Plot with Target'):
    with plt.style.context('fivethirtyeight'):
        # Create a figure with two subplots
        fig, axes = plt.subplots(1, 2, figsize=(12, 6))

        # Plot the scatter plot on the first subplot
        scatterplot1 = sns.scatterplot(x=x_feature, y=y_feature, data=df, color='#512b58', ax=axes[0])
        axes[0].set_title(title1)

        # Plot the scatter plot on the second subplot
        scatterplot2 = sns.scatterplot(x=x_feature, y=y_feature, data=df, hue=hue_feature, palette=palette, ax=axes[1])

        handles, labels = scatterplot2.get_legend_handles_labels()
        labels = [label_mapping[int(label)] for label in labels]
        scatterplot2.legend(handles, labels)
        axes[1].set_title(title2)

        # Adjust layout
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Diastolic Pressure & Systolic Pressure</h3>

# %%
dual_scatter_plot(df, 'Diastolic blood pressure', 'Systolic blood pressure')

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Statistical & Hypothesis Tests</h3>

# %% [markdown]
# # </a>
# <h3 style="background-color:#e7fbf8;font-family:newtimeroman;font-size:210%;text-align:center;border-radius: 15px 50px;">Anova Test</h3>

# %% [markdown]
# The ANOVA test is used to analyze whether there are significant differences in means between groups. In our case, we are comparing the means of the continuous features such as : age, BMI, blood pressure ...etc across different groups defined by the categorical features such as : CHD. Diabetes, hypertension ...etc
#
# The results of anova test involve :
# - F-Statistic: It measures the ratio of the between-group variability to the within-group variability. Higher values of the F-statistic indicate larger differences between the group means.
# - p-value: It represents the probability of observing the F-statistic or a more extreme value if the null hypothesis (no difference between group means) is true. A small p-value (typically less than 0.05) suggests strong evidence against the null hypothesis.

# %%
def perform_anova_test(df, categorical_feature):

    # Perform ANOVA for each continuous feature
    anova_results = []
    for continuous_feature in continuous_features:
        groups = []
        for group_name, group_data in df.groupby(categorical_feature):
            groups.append(group_data[continuous_feature].values)
        
        anova_result = stats.f_oneway(*groups)
        anova_results.append((continuous_feature, round(anova_result.statistic,2), anova_result.pvalue))
    
    # Create a DataFrame from the ANOVA results
    anova_results_df = pd.DataFrame(anova_results, columns=['Continuous Feature', 'F-Statistic', 'p-value'])
    
    # Set the Continuous Feature column as the index
    anova_results_df.set_index('Continuous Feature', inplace=True)
    
    # Sort the DataFrame by p-value in ascending order
    anova_results_df = anova_results_df.sort_values('p-value')
    
    return anova_results_df

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">MI</h3>

# %%
perform_anova_test(df, 'MI')
# Out:
#                           F-Statistic       p-value
# Continuous Feature
# Age                             79.15  1.861645e-18
# Troponin                        73.14  3.303209e-17
# CK-MB                           65.53  1.287762e-15
# Blood sugar                      1.44  2.302000e-01
# Systolic blood pressure          0.57  4.498359e-01
# Diastolic blood pressure         0.12  7.259839e-01
# Heart rate                       0.06  8.017343e-01

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Outliers handling discussion</h3>

# %% [markdown]
# During our examination of the dataset, we observed the presence of outliers in various features, as indicated by statistical measures such as box plots and histograms we have built before. These outliers were defined as values that **exceeded the range of Q3 + 1.5 IQR (interquartile range) or were below Q1 - 1.5 IQR**. However, we subsequently engaged in discussions with domain experts in the medical field to gain a deeper understanding of these outliers.
#
# The insights provided by **medical domain experts** played a crucial role in our decision-making process. We learned that the outliers we initially identified actually represent valid and plausible data points that **can exist in the real world. These values are not errors or noise but rather reflect extreme occurrences** that can contribute to a comprehensive understanding of the factors associated with CHD.
#
# Based on these discussions and the validation of the outliers, we have made the **informed decision to retain them in our analysis**.
#
# By doing so, we aim to **capture the full range of real-world scenarios and avoid introducing bias into our findings**.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Models Development</h3>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Importing Libraries</h3>

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
import joblib
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc, precision_recall_curve, cohen_kappa_score, matthews_corrcoef

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Data Scaling</h3>

# %%
categorical = [col for col in df.columns if df[col].dtype == "O"]
categorical
# Out:
# ['Gender']

# %%
numerical = [col for col in df.columns if df[col].dtype != "O"]
numerical = numerical[0:-1]
numerical
# Out:
# ['Age',
#  'Heart rate',
#  'Systolic blood pressure',
#  'Diastolic blood pressure',
#  'Blood sugar',
#  'CK-MB',
#  'Troponin']

# %%
X = df.drop('MI', axis=1)
Y = df['MI']

X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size=0.15, random_state=42, stratify=Y)

pipeline = ColumnTransformer([("scaler", StandardScaler() ,numerical ),
                               ("encoder", OneHotEncoder() , categorical)
                             ])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
joblib.dump(pipeline, "pipeline.joblib")
# Out:
# ['pipeline.joblib']

# %%
pipeline
# Out:
# ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                  ['Age', 'Heart rate',
#                                   'Systolic blood pressure',
#                                   'Diastolic blood pressure', 'Blood sugar',
#                                   'CK-MB', 'Troponin']),
#                                 ('encoder', OneHotEncoder(), ['Gender'])])

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#f8fefd; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Modeling</h3>

# %%
def evaluate_classifier(name, classifier, params, X_train=X_train, Y_train=Y_train, X_test=X_test, Y_test=Y_test):
    cv = GridSearchCV(classifier, params, cv=3)
    cv.fit(X_train, Y_train)

    # Predict the target variable for the test set
    Y_pred = cv.predict(X_test)
    Y_prob = cv.predict_proba(X_test)[:, 1]  # Probability estimates for the positive class

    # Compute metrics
    accuracy = cv.score(X_test, Y_test)
    f1 = f1_score(Y_test, Y_pred)
    precision = precision_score(Y_test, Y_pred)
    recall = recall_score(Y_test, Y_pred)

    # Print the metrics
    print(f'Classifier: {name}')
    print(f'Best Parameters: {cv.best_params_}')
    print(f'Accuracy: {accuracy:.2f}')
    print(f'F1 Score: {f1:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(classification_report(Y_test, Y_pred))

    # Confusion Matrix
    cm = confusion_matrix(Y_test, Y_pred)
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Purples')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    # ROC & AUC Curve
    fpr, tpr, _ = roc_curve(Y_test, Y_prob)
    roc_auc = auc(fpr, tpr)
    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, color='#593961', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.show()

    # Precision-Recall Curve
    precision_vals, recall_vals, _ = precision_recall_curve(Y_test, Y_prob)
    plt.figure(figsize=(6, 6))
    plt.plot(recall_vals, precision_vals, color='#126f63', lw=2)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.show()

# %%
# Define the logistic regression classifier with its corresponding hyperparameters
logistic_regression_params = {
    'C': [0.1, 1, 10],
    'penalty': ['l2'],
}

logistic_regression_classifier = LogisticRegression()

# Use the evaluate_classifier function to evaluate the logistic regression classifier
evaluate_classifier('Logistic Regression', logistic_regression_classifier, logistic_regression_params)
# Out:
# Classifier: Logistic Regression
# Best Parameters: {'C': 10, 'penalty': 'l2'}
# Accuracy: 0.79
# F1 Score: 0.83
# Precision: 0.85
# Recall: 0.81
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74        76
#            1       0.85      0.81      0.83       122
#
#     accuracy                           0.79       198
#    macro avg       0.78      0.79      0.78       198
# weighted avg       0.80      0.79      0.79       198

# %%
# Define the KNN classifier with its corresponding hyperparameters
knn_params = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance']
}

knn_classifier = KNeighborsClassifier()

# Use the evaluate_classifier function to evaluate the KNN classifier
evaluate_classifier('KNN', knn_classifier, knn_params)
# Out:
# Classifier: KNN
# Best Parameters: {'n_neighbors': 7, 'weights': 'uniform'}
# Accuracy: 0.64
# F1 Score: 0.69
# Precision: 0.73
# Recall: 0.66
#               precision    recall  f1-score   support
#
#            0       0.52      0.61      0.56        76
#            1       0.73      0.66      0.69       122
#
#     accuracy                           0.64       198
#    macro avg       0.62      0.63      0.63       198
# weighted avg       0.65      0.64      0.64       198

# %%
# Define the SVM classifier with its corresponding hyperparameters
svm_params = {
    'C': [0.1, 1, 10],
    'gamma': [0.1, 0.01, 0.001]
}

svm_classifier = SVC(probability=True)

# Use the evaluate_classifier function to evaluate the SVM classifier
evaluate_classifier('SVM', svm_classifier, svm_params)
# Out:
# Classifier: SVM
# Best Parameters: {'C': 10, 'gamma': 0.1}
# Accuracy: 0.80
# F1 Score: 0.83
# Precision: 0.85
# Recall: 0.82
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74        76
#            1       0.85      0.82      0.83       122
#
#     accuracy                           0.80       198
#    macro avg       0.79      0.79      0.79       198
# weighted avg       0.80      0.80      0.80       198

# %%
# Define the Decision Tree classifier with its corresponding hyperparameters
decision_tree_params = {
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

decision_tree_classifier = DecisionTreeClassifier()

# Use the evaluate_classifier function to evaluate the Decision Tree classifier
evaluate_classifier('Decision Tree', decision_tree_classifier, decision_tree_params)
# Out:
# Classifier: Decision Tree
# Best Parameters: {'max_depth': None, 'min_samples_split': 10}
# Accuracy: 0.98
# F1 Score: 0.98
# Precision: 0.98
# Recall: 0.98
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        76
#            1       0.98      0.98      0.98       122
#
#     accuracy                           0.98       198
#    macro avg       0.98      0.98      0.98       198
# weighted avg       0.98      0.98      0.98       198

# %%
# Define the Random Forest classifier with its corresponding hyperparameters
random_forest_params = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10]
}

random_forest_classifier = RandomForestClassifier()

# Use the evaluate_classifier function to evaluate the Random Forest classifier
evaluate_classifier('Random Forest', random_forest_classifier, random_forest_params)
# Out:
# Classifier: Random Forest
# Best Parameters: {'max_depth': None, 'n_estimators': 300}
# Accuracy: 0.98
# F1 Score: 0.98
# Precision: 0.98
# Recall: 0.98
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        76
#            1       0.98      0.98      0.98       122
#
#     accuracy                           0.98       198
#    macro avg       0.98      0.98      0.98       198
# weighted avg       0.98      0.98      0.98       198

# %%
# Define the Extra tree classifier with its corresponding hyperparameters
extra_trees_params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

extra_trees_classifier = ExtraTreesClassifier()

# Use the evaluate_classifier function to evaluate the Extra tree classifier
evaluate_classifier('Extra Trees', extra_trees_classifier, extra_trees_params)
# Out:
# Classifier: Extra Trees
# Best Parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.97
# F1 Score: 0.98
# Precision: 0.98
# Recall: 0.98
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        76
#            1       0.98      0.98      0.98       122
#
#     accuracy                           0.97       198
#    macro avg       0.97      0.97      0.97       198
# weighted avg       0.97      0.97      0.97       198

# %%
# Define the XGBoost classifier with its corresponding hyperparameters
xgboost_params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01,0.1, 0.2]
}

xgboost_classifier = XGBClassifier()

# Use the evaluate_classifier function to evaluate the XGBoost classifier
evaluate_classifier('XGBoost', xgboost_classifier, xgboost_params)
# Out:
# Classifier: XGBoost
# Best Parameters: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}
# Accuracy: 0.98
# F1 Score: 0.98
# Precision: 0.98
# Recall: 0.98
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        76
#            1       0.98      0.98      0.98       122
#
#     accuracy                           0.98       198
#    macro avg       0.98      0.98      0.98       198
# weighted avg       0.98      0.98      0.98       198

# %%
rf =  RandomForestClassifier()
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# This results satisfies with the National Institute of Health and National Center for Biotechnology Information **(NCBI)** recommendations that  **"Although CK-MB has a high sensitivity for cardiac myocytes, it should not be used as a first-line diagnostic test if cardiac troponin assays are available. In the absence of cardiac troponin assays, CK-MB can be useful in the evaluation of acute MI, but it is far less sensitive and specific than cardiac troponins"**
#
# For more medical information and resources related to this
# https://www.ncbi.nlm.nih.gov/books/NBK545216/

# %%
joblib.dump(rf, 'model.joblib')
# Out:
# ['model.joblib']

# %%
del rf

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Data Correlation</h3>

# %%
df['Gender'] = df['Gender'].map({ 'male' : 1 , 'female' : 0 })

# %%
df.corr()
# Out:
#                                Age    Gender  Heart rate  \
# Age                       1.000000 -0.092874   -0.023440
# Gender                   -0.092874  1.000000   -0.026781
# Heart rate               -0.023440 -0.026781    1.000000
# Systolic blood pressure   0.017441  0.011065    0.010882
# Diastolic blood pressure  0.002614 -0.009370    0.108353
# Blood sugar              -0.004193  0.006668   -0.019584
# CK-MB                     0.018419  0.017527   -0.013001
# Troponin                  0.088800  0.065793    0.011180
# MI                        0.238097  0.094432    0.006920
#
#                           Systolic blood pressure  Diastolic blood pressure  \
# Age                                      0.017441                  0.002614
# Gender                                   0.011065                 -0.009370
# Heart rate                               0.010882                  0.108353
# Systolic blood pressure                  1.000000                  0.586166
# Diastolic blood pressure                 0.586166                  1.000000
# Blood sugar                              0.020807                 -0.025614
# CK-MB                                   -0.016396                 -0.023403
# Troponin                                 0.043729                  0.043360
# MI                                      -0.020825                 -0.009659
#
#                           Blood sugar     CK-MB  Troponin        MI
# Age                         -0.004193  0.018419  0.088800  0.238097
# Gender                       0.006668  0.017527  0.065793  0.094432
# Heart rate                  -0.019584 -0.013001  0.011180  0.006920
# Systolic blood pressure      0.020807 -0.016396  0.043729 -0.020825
# Diastolic blood pressure    -0.025614 -0.023403  0.043360 -0.009659
# Blood sugar                  1.000000  0.045757  0.021069 -0.033059
# CK-MB                        0.045757  1.000000 -0.016008  0.217720
# Troponin                     0.021069 -0.016008  1.000000  0.229376
# MI                          -0.033059  0.217720  0.229376  1.000000

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(), annot=True, annot_kws={"size": 15}, cmap='Purples')

plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:#c5f6ef;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Deployment</h3>

# %%
input_data = {
 'Age': 60,
 'Gender': 'male',
 'Heart rate': 77,
 'Systolic blood pressure': 120,
 'Diastolic blood pressure': 50,
 'Blood sugar': 240,
 'CK-MB' : 14,
 'Troponin' : 0.12 
  }

# %%
del pipeline

# %%
pipeline = joblib.load("pipeline.joblib")

# %%
model = joblib.load("model.joblib")

# %%
def perform_prediction(input_data, pipeline, model):
    
    intput_df = pd.DataFrame(input_data, index=[0])
    
    preprocessed_data = pipeline.transform(intput_df)
    
    prediction = model.predict(preprocessed_data)
    
    return {"prediction":prediction[0]}

# %%
perform_prediction(input_data,pipeline,model)
# Out:
# {'prediction': 1}
