# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:lightsteelblue;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;"> CK-MB & Troponin Tests Notebook </h1>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Introduction</h3>

# %% [markdown]
# Cardiac emergencies are the leading cause of mortality worldwide. In a cardiac emergency, the two pillars that facilitate the right diagnosis and treatment are; the time and accuracy of every verbal or diagnostic information. Both of these have a critical effect on the outcomes of the cardiac patient.
#
# CK-MB and troponin tests are essential diagnostic tools for heart attack evaluation. These tests provide valuable information about the presence, extent, and progression of heart muscle damage, enabling prompt diagnosis, appropriate treatment, and effective monitoring of heart health.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Vision</h3>

# %% [markdown]
# Our vision involves integrating the troponin test and CK-MB results with the analysis of 12-lead ECG to enhance our ability to detect **MI (heart attack)** and identify any abnormalities. By combining these diagnostic factors, we aim to create a comprehensive and robust system that leverages multiple sources of information to improve the accuracy and reliability of our detection model.
#
# The **troponin test** measures the level of troponin, a protein found in the cells of the heart muscle, in a person's blood. Elevated troponin levels indicate damage to the heart muscle, such as that caused by a heart attack.
#
# Additionally, we will incorporate the **CK-MB test**, which looks for a specific enzyme in the blood to diagnose or rule out a heart attack. Although the CK-MB test is no longer the primary choice for diagnosing heart attacks, it can still provide relevant information when combined with other diagnostic factors.
#
# By considering CK-MB results alongside the troponin test and 12-lead ECG analysis, we can gain a more comprehensive understanding of a person's cardiac health.
#
# By combining these diagnostic factors together through detection approach in our project, our vision is to develop a system that provides an in-depth and accurate assessment of a person's risk of MI and identifies any abnormalities in their cardiac health. This integrated approach will enable us to deliver more **reliable results** and facilitate timely medical intervention and treatment, ultimately improving patient outcomes.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">DataSet Overview</h3>

# %% [markdown]
#  This heart attack dataset was collected at Zheen hospital in Erbil, Iraq, from January 2019 to May 2019.
#
# The attributes of this dataset are: age, gender, heart rate, systolic blood pressure, diastolic blood pressure, blood sugar, ck-mb and troponin with negative or positive output.
#
# According to the provided information, the medical dataset classifies either heart attack or none. The gender column in the data is normalized: the male is set to 1 and the female to 0. The glucose column is set to 1 if it is > 120; otherwise, 0. As for the output, positive is set to 1 and negative to 0.
#
# The link of the dataset is provided here https://data.mendeley.com/datasets/wmhctcrt5v/1

# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Medical Background </h1>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Cardiovascular systemt</h3>

# %% [markdown]
# The cardiovascular system, also known as the circulatory system, is a vital network of organs, vessels, and tissues responsible for transporting blood, oxygen, nutrients, and waste products throughout the body. It plays a crucial role in maintaining homeostasis and supporting various bodily functions. The key components of the cardiovascular system include the heart, blood vessels, and blood.

# %%
from IPython.display import Image
Image(filename='Human-Circulatory-System-Transportation.png',width=900,height=400)

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Myocardial Infarction (MI)</h3>

# %% [markdown]
# A myocardial infarction (MI), commonly known as a heart attack, is an extremely dangerous condition that occurs when blood flow decreases or stops in one of the coronary arteries of the heart, causing infarction (tissue death) to the heart muscle.

# %%
Image(filename='Heart Attack.jpg',width=900,height=400)

# %% [markdown]
# Most MIs occur due to coronary artery disease ,which is considered a crucial concern that we have also worked on through the Framingham heart study dataset through our graduation project,.
#
# Risk factors of MI include family history of heart disease, high blood pressure, smoking, diabetes, lack of exercise, obesity, high blood cholesterol.

# %%
Image(filename='MI.png',width=900,height=400)

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Troponin Test</h3>

# %% [markdown]
# A troponin test measures the level of troponin in a sample of your blood. Troponin is a protein that's found in the cells of your heart muscle.
#
# Normally, troponin levels in blood are so low that only the most sensitive types of tests can measure them. But if your heart muscle is damaged, troponin leaks into your bloodstream, and your troponin blood levels will rise.
#
# Troponin testing is mainly used to help diagnose heart attacks. Heart attacks damage the heart by suddenly blocking the blood flow that brings oxygen to part of the heart muscle. Without oxygen from blood, heart muscle cells die and release troponin.
#
# Troponin test results can confirm damage to the heart muscle from a heart attack. The more damage there is to the heart, the more troponin is released into the blood. So, measuring the amount of troponin in the blood can also help estimate how much of the heart has been damaged. Higher than normal troponin levels may also be found in other conditions that can damage heart muscle.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">What is it used for?</h3>

# %% [markdown]
# - Confirm if a person is having a heart attack or recently had a heart attack. This is the most common reason for troponin testing. The test is usually done in the emergency room of a hospital along with other heart tests, such as an EKG (also called an ECG or electrocardiogram).
# - Diagnose and monitor unstable angina. Angina is chest pain that happens if part of the heart muscle doesn't get as much blood as it needs. Unstable angina is a type of angina that happens at any time, even during rest. It's a medical emergency because it can lead to a heart attack.

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">CK-MB Test</h3>

# %% [markdown]
# The CK-MB test is a test that looks for a specific type of enzyme in your blood to diagnose or rule out a heart attack. However, CK-MB is no longer the blood test of choice for diagnosing heart attacks, and many hospitals no longer use it because there are better test methods available (the cardiac troponin tests are currently the tests of choice).

# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;"> Libraries & loading the data</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Load the dataset
df = pd.read_csv("MI.csv")

# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;"> Exploratory Data Analysis</h1>

# %%
print(f'No. of records are {df.shape[0]}')
print(f'No. of columns are {df.shape[1]}')
# Out:
# No. of records are 1319
# No. of columns are 9

# %%
df.head()
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive
# 4        300.0   1.08     0.003  negative

# %%
column = list(df.columns)
categorical_features = []
discrete_features = []

for i in column:
    if len(df[i].unique()) > 6:
        discrete_features.append(i)
    else:
        categorical_features.append(i)

print('Categorical Features :',*categorical_features)
print('Continous Features :',*discrete_features)
# Out:
# Categorical Features : Gender Result
# Continous Features : Age Heart rate Systolic blood pressure Diastolic blood pressure Blood sugar CK-MB Troponin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
round(df.describe())
# Out:
#           Age  Gender  Heart rate  Systolic blood pressure  \
# count  1319.0  1319.0      1319.0                   1319.0
# mean     56.0     1.0        78.0                    127.0
# std      14.0     0.0        52.0                     26.0
# min      14.0     0.0        20.0                     42.0
# 25%      47.0     0.0        64.0                    110.0
# 50%      58.0     1.0        74.0                    124.0
# 75%      65.0     1.0        85.0                    143.0
# max     103.0     1.0      1111.0                    223.0
#
#        Diastolic blood pressure  Blood sugar   CK-MB  Troponin
# count                    1319.0       1319.0  1319.0    1319.0
# mean                       72.0        147.0    15.0       0.0
# std                        14.0         75.0    46.0       1.0
# min                        38.0         35.0     0.0       0.0
# 25%                        62.0         98.0     2.0       0.0
# ...

# %%
# Remove duplicates if any
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %%
# Mapping the categorical toarget to 1 if positive and 0 if negative
df['MI'] = df['Result'].map({'positive': 1, 'negative': 0})

# %%
df=df.drop('Result',axis=1)

# %%
df['Gender'] = df['Gender'].map({1 : 'male', 0 : 'female'})

# %%
df.to_csv("updated_MI.csv")

# %%
df.head()
# Out:
#    Age Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64   male          66                      160                        83
# 1   21   male          94                       98                        46
# 2   55   male          64                      160                        77
# 3   64   male          70                      120                        55
# 4   55   male          64                      112                        65
#
#    Blood sugar  CK-MB  Troponin  MI
# 0        160.0   1.80     0.012   0
# 1        296.0   6.75     1.060   1
# 2        270.0   1.99     0.003   0
# 3        270.0  13.87     0.122   1
# 4        300.0   1.08     0.003   0

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Target distribution</h3>

# %%
# let us overview the distribution of the target of our data
x = pd.DataFrame(df.groupby(['MI'])['MI'].count())

# Plot
fig, ax = plt.subplots(figsize=(7, 7), dpi=60)
ax.barh([1], x.MI[1], height=0.7, color='#fe346e')
plt.text(-200, -0.08, 'Healthy', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'style': 'normal', 'color': '#3081D0'})
plt.text(900, -0.08, '38.6%', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'color': '#3081D0'})
ax.barh([0], x.MI[0], height=0.7, color='#3081D0')
plt.text(-100, 1, 'MI', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'style': 'normal', 'color': '#fe346e'})
plt.text(900, 1, '61.4%', {'font': 'Serif', 'weight': 'bold', 'size': '16', 'color': '#fe346e'})

fig.patch.set_facecolor('white')
ax.set_facecolor('white')

plt.text(-1150, 1.77, 'Percentage of People at Risk of Myocardial Infarction (MI)', {'font': 'Serif', 'size': '25', 'weight': 'bold', 'color': 'black'})

ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Data Visualization Functions</h3>

# %% [markdown]
# There are many different types of graphs, each with its own unique properties and applications.
#
# We will use :
#
# 1- **Pie plot** : for categorical data
#
# 2- **KDE plot** : (kernel density estimation plot) : for numerical data
#
# 3- **Box Plot** : for definition of outliers in numerical data
#
# 4- **Histogram** : distribution of numerical data

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Catigorical data</h3>

# %%
def pie_plot(df, group_feature, overall_title, colors):
    # Calculate percentage of each category in the group feature
    grouped = df[group_feature].value_counts(normalize=True).rename('percentage').mul(100).reset_index()

    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(figsize=(8, 6))

        wedges, texts, autotexts = ax.pie(grouped['percentage'], labels=grouped['index'],
                                           autopct='%1.1f%%', colors=colors)
        ax.set_title(f'Distribution of {overall_title}')  # Set the title to be the group feature
        plt.setp(autotexts, size=16, color="w")

        plt.tight_layout()
        plt.show()

# %%
def pie_with_target(df, group_feature, overall_title):
    # Calculate percentage of people who developed MI for each group
    grouped = df.groupby(group_feature)['MI'].value_counts(normalize=True).rename('percentage').mul(100).reset_index()

    # Define custom color palette
    custom_palette = {0: '#3081D0', 1: '#fe346e'}
    # Define custom legend labels
    legend_labels = {0: 'Negative', 1: 'Positive'}

    unique_groups = grouped[group_feature].unique()
    num_unique_groups = len(unique_groups)

    # Ensure all MI statuses are in custom_palette and legend_labels
    assert set(grouped['MI'].unique()).issubset(custom_palette.keys()), "All MI statuses must be keys in custom_palette"
    assert set(grouped['MI'].unique()).issubset(legend_labels.keys()), "All MI statuses must be keys in legend_labels"

    with plt.style.context('fivethirtyeight'):
        fig, axs = plt.subplots(1, num_unique_groups, figsize=(15, 6))

        if num_unique_groups == 1:
            axs = [axs]  # To handle the case where there is only 1 group

        for i, group_status in enumerate(unique_groups):
            data = grouped[grouped[group_feature]== group_status ]
            labels = data['MI'].map(legend_labels).tolist() # map stroke status to labels
            colors = data['MI'].map(custom_palette).tolist() # map stroke status to colors
            wedges, texts, autotexts = axs[i].pie(data['percentage'], labels=labels, colors=colors, autopct='%1.1f%%')

            axs[i].set_title(f'{group_status}')  # Set the title to be the group feature and status
            plt.setp(autotexts, size=16, color="w")
        
        
        fig.suptitle(f'Percentage of people who developed MI grouped by {overall_title} status', fontsize=18)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Continuous data</h3>

# %%
def plot_distribution(df, feature, plot_title):
    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(1, 2, figsize=(20, 5))

        # Histogram
        sns.histplot(x=feature,
                     data=df, 
                     ax=ax[0],
                     linewidth=0.8,
                     color='#3081D0',
                     bins=20).set_title(f"Distribution of {plot_title}")
        ax[0].set_xlabel(plot_title)

        # Box plot for the entire distribution
        sns.boxplot(x=feature,
                    data=df,
                    linewidth=1.5,
                    width=0.5,
                    color='#3081D0',
                    ax=ax[1]).set_title(f"Box Plot of {plot_title}")
        ax[1].set_xlabel(plot_title)

        plt.show()

# %%
df['MI'] = df['MI'].map({1: 'MI', 0: 'Healthy'})
def plot_MI_vs_Healthy(feature, plot_title, df = df):
    box_plots_colors = {'Healthy': '#3081D0', 'MI':'#fe346e'}
    
    with plt.style.context('fivethirtyeight'):
        fig, ax = plt.subplots(1, 2, figsize=(20, 5))

        # KDE plot for MI vs Healthy
        sns.kdeplot(data=df[df['MI']=='MI'], x=feature, color='#fe346e', fill=True, linewidth=1.5, ec='black', alpha=0.8, zorder=3, ax=ax[0])
        sns.kdeplot(data=df[df['MI']=='Healthy'], x=feature, color='#3081D0', fill=True, linewidth=1.5, ec='black', alpha=0.8, zorder=3, ax=ax[0])

        ax[0].set_title(f"KDE Plot of {plot_title} by MI")
        ax[0].set_xlabel(plot_title)
        ax[0].set_ylabel('Density')

        # Box plot for MI vs Healthy
        sns.boxplot(x=feature,
                    data=df,
                    y="MI",
                    linewidth=1.5,
                    palette=box_plots_colors,
                    ax=ax[1]).set_title(f"Distribution of {plot_title} by MI")
        ax[1].set_xlabel(plot_title)
        ax[1].set_ylabel('MI')

        plt.show()

# %% [markdown]
# # <a id="2.2"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Feature Statistics Functions</h3>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Catigorical data</h3>

# %%
def explore_categorical_variable(feature, data = df):
    # Extract the column from the dataset
    column = data[feature]
    
    # Data type
    data_type = column.dtype
    
    # Count of each category
    count = column.count()
    
    # Mode (most frequent category)
    mode = column.mode().iloc[0]
    
    unique_values = column.nunique()
    
    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Data Type', 'Count', 'Mode', 'Num of Possible values'],
        'Values': [data_type, count,  mode , unique_values ]
    })
    
    # Remove the index column
    results_df = results_df.reset_index(drop=True)
    
    return results_df

# %%
def explore_categories(feature_name, category_names, data=df):
    
    # Extract the column from the dataset
    column = data[feature_name]

    # Data type
    data_type = str(column.dtype)

    # Count of each category
    category_counts = column.value_counts()

    # Percentage of each category
    category_percentages = {category: count / column.count() * 100 for category, count in category_counts.items()}

    # Create a DataFrame for count, percentage, data type, and mode
    result_df = pd.DataFrame({
        f'{feature_name}': category_counts.index,
        'Count': category_counts.values,
        'Percentage': [category_percentages.get(category, 0) for category in category_counts.index],
    })

    # Formatting for Percentage column
    result_df['Percentage'] = result_df['Percentage'].round(2)

    return result_df

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Continuous data</h3>

# %%
def explore_continuous_variable(feature, data=df):
    # Extract the column from the dataset
    column = data[feature]
    
    # Data type
    data_type = column.dtype
    
    # Basic statistics
    minimum = int(column.min())
    maximum = int(column.max())
    data_range = maximum - minimum
    mean = round(column.mean())
    median = int(column.median())
    q3 = int(column.quantile(0.75))
    q1 = int(column.quantile(0.25))
    iqr = q3 - q1
    variance = round(column.var(), 2)
    std_deviation = round(column.std(), 2)
    coefficient_of_variation = round(np.sqrt(variance) / mean, 2)
    skewness = round(column.skew(), 2)
    
    # Percentiles
    percentiles = column.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])
    
    # Number of null values
    num_null_values = column.isnull().sum()
    
    # Calculate outliers based on IQR
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers_percentage = round(((column < lower_bound) | (column > upper_bound)).mean() * 100, 2)
    
    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Feature', 'Data Type', 'Minimum Value', 'Maximum Value', 'Range', 'Mean', 'Median', 'Q3', 'Q1',
                       'IQR', 'Outliers Percentage', 'Variance', 'Standard Deviation', 'Coefficient of Variation', 'Skewness',
                       '10th Percentile', '25th Percentile', '50th Percentile', '75th Percentile', '90th Percentile',
                       'Number of Null Values','Lower Band' , 'Upper Band'],
        'Values': [feature, data_type, minimum, maximum, data_range, mean, median, q3, q1, iqr, outliers_percentage, variance, std_deviation,
                   coefficient_of_variation, skewness, int(percentiles['10%']), int(percentiles['25%']),
                   int(percentiles['50%']), int(percentiles['75%']), int(percentiles['90%']), num_null_values , lower_bound , upper_bound  
                   ]
    })
    
    results_df = results_df.reset_index(drop=True)
    
    # Create a Styler object
    styled_df = results_df.style.set_properties(**{'text-align': 'center'})
    
    return styled_df

# %%
def compare_feature_statistics(feature, data=df):
    # Extract the column for MI and Healthy individuals
    MI_column = data[data['MI'] == 1][feature]
    healthy_column = data[data['MI'] == 0][feature]

    # Basic statistics for MI
    MI_mean = int(MI_column.mean())
    MI_median = int(MI_column.median())
    MI_std_deviation = round(MI_column.std(), 2)
    MI_min = int(MI_column.min())
    MI_max = int(MI_column.max())
    MI_iqr = int(MI_column.quantile(0.75) - MI_column.quantile(0.25))

    # Basic statistics for Healthy
    healthy_mean = int(healthy_column.mean())
    healthy_median = int(healthy_column.median())
    healthy_std_deviation = round(healthy_column.std(), 2)
    healthy_min = int(healthy_column.min())
    healthy_max = int(healthy_column.max())
    healthy_iqr = int(healthy_column.quantile(0.75) - healthy_column.quantile(0.25))

    # Create a DataFrame to store the results
    results_df = pd.DataFrame({
        'Statistics': ['Mean', 'Median', 'Std Deviation', 'Min', 'Max', 'IQR'],
        'MI': [MI_mean, MI_median, MI_std_deviation, MI_min, MI_max, MI_iqr],
        'Healthy': [healthy_mean, healthy_median, healthy_std_deviation, healthy_min, healthy_max, healthy_iqr]
    })

    results_df = results_df.set_index('Statistics')
    
    results_df = results_df.astype(int)

    # Create a Styler object
    styled_df = results_df.style.set_properties(**{'text-align': 'center'})

    return styled_df

# %% [markdown]
# # <a id="2"></a>
# <h1 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;"> Features</h1>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Age</h3>

# %%
explore_continuous_variable('Age')
# Out:
# <style  type="text/css" >
# #T_7298e_row0_col0,#T_7298e_row0_col1,#T_7298e_row1_col0,#T_7298e_row1_col1,#T_7298e_row2_col0,#T_7298e_row2_col1,#T_7298e_row3_col0,#T_7298e_row3_col1,#T_7298e_row4_col0,#T_7298e_row4_col1,#T_7298e_row5_col0,#T_7298e_row5_col1,#T_7298e_row6_col0,#T_7298e_row6_col1,#T_7298e_row7_col0,#T_7298e_row7_col1,#T_7298e_row8_col0,#T_7298e_row8_col1,#T_7298e_row9_col0,#T_7298e_row9_col1,#T_7298e_row10_col0,#T_7298e_row10_col1,#T_7298e_row11_col0,#T_7298e_row11_col1,#T_7298e_row12_col0,#T_7298e_row12_col1,#T_7298e_row13_col0,#T_7298e_row13_col1,#T_7298e_row14_col0,#T_7298e_row14_col1,#T_7298e_row15_col0,#T_7298e_row15_col1,#T_7298e_row16_col0,#T_7298e_row16_col1,#T_7298e_row17_col0,#T_7298e_row17_col1,#T_7298e_row18_col0,#T_7298e_row18_col1,#T_7298e_row19_col0,#T_7298e_row19_col1,#T_7298e_row20_col0,#T_7298e_row20_col1,#T_7298e_row21_col0,#T_7298e_row21_col1,#T_7298e_row22_col0,#T_7298e_row22_col1{
#             text-align:  center;
# ...

# %%
plot_distribution(df, 'Age', 'Age')

# %%
compare_feature_statistics('Age')
# Out:
# <style  type="text/css" >
# #T_12f5d_row0_col0,#T_12f5d_row0_col1,#T_12f5d_row1_col0,#T_12f5d_row1_col1,#T_12f5d_row2_col0,#T_12f5d_row2_col1,#T_12f5d_row3_col0,#T_12f5d_row3_col1,#T_12f5d_row4_col0,#T_12f5d_row4_col1,#T_12f5d_row5_col0,#T_12f5d_row5_col1{
#             text-align:  center;
#         }</style><table id="T_12f5d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12f5d_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_12f5d_row0_col0" class="data row0 col0" >58</td>
#                         <td id="T_12f5d_row0_col1" class="data row0 col1" >52</td>
#             </tr>
#             <tr>
# ...

# %%
plot_MI_vs_Healthy("Age", "Age")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Gender</h3>

# %%
explore_categorical_variable('Gender')
# Out:
#                Statistics  Values
# 0               Data Type  object
# 1                   Count    1319
# 2                    Mode    male
# 3  Num of Possible values       2

# %%
pie_plot(df, 'Gender', 'Gender', colors=['#3081D0','#fe346e'])

# %%
explore_categories('Gender',['male','female'])
# Out:
#    Gender  Count  Percentage
# 0    male    870       65.96
# 1  female    449       34.04

# %%
pie_with_target(df, 'Gender', 'Gender')

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Heart rate</h3>

# %%
explore_continuous_variable('Heart rate')
# Out:
# <style  type="text/css" >
# #T_f8da5_row0_col0,#T_f8da5_row0_col1,#T_f8da5_row1_col0,#T_f8da5_row1_col1,#T_f8da5_row2_col0,#T_f8da5_row2_col1,#T_f8da5_row3_col0,#T_f8da5_row3_col1,#T_f8da5_row4_col0,#T_f8da5_row4_col1,#T_f8da5_row5_col0,#T_f8da5_row5_col1,#T_f8da5_row6_col0,#T_f8da5_row6_col1,#T_f8da5_row7_col0,#T_f8da5_row7_col1,#T_f8da5_row8_col0,#T_f8da5_row8_col1,#T_f8da5_row9_col0,#T_f8da5_row9_col1,#T_f8da5_row10_col0,#T_f8da5_row10_col1,#T_f8da5_row11_col0,#T_f8da5_row11_col1,#T_f8da5_row12_col0,#T_f8da5_row12_col1,#T_f8da5_row13_col0,#T_f8da5_row13_col1,#T_f8da5_row14_col0,#T_f8da5_row14_col1,#T_f8da5_row15_col0,#T_f8da5_row15_col1,#T_f8da5_row16_col0,#T_f8da5_row16_col1,#T_f8da5_row17_col0,#T_f8da5_row17_col1,#T_f8da5_row18_col0,#T_f8da5_row18_col1,#T_f8da5_row19_col0,#T_f8da5_row19_col1,#T_f8da5_row20_col0,#T_f8da5_row20_col1,#T_f8da5_row21_col0,#T_f8da5_row21_col1,#T_f8da5_row22_col0,#T_f8da5_row22_col1{
#             text-align:  center;
# ...

# %%
plot_distribution(df, 'Heart rate', 'Heart rate')

# %%
compare_feature_statistics('Heart rate')
# Out:
# <style  type="text/css" >
# #T_14e81_row0_col0,#T_14e81_row0_col1,#T_14e81_row1_col0,#T_14e81_row1_col1,#T_14e81_row2_col0,#T_14e81_row2_col1,#T_14e81_row3_col0,#T_14e81_row3_col1,#T_14e81_row4_col0,#T_14e81_row4_col1,#T_14e81_row5_col0,#T_14e81_row5_col1{
#             text-align:  center;
#         }</style><table id="T_14e81_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14e81_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_14e81_row0_col0" class="data row0 col0" >78</td>
#                         <td id="T_14e81_row0_col1" class="data row0 col1" >77</td>
#             </tr>
#             <tr>
# ...

# %%
plot_MI_vs_Healthy("Heart rate", "Heart rate")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Systolic blood pressure</h3>

# %%
explore_continuous_variable('Systolic blood pressure')
# Out:
# <style  type="text/css" >
# #T_05bad_row0_col0,#T_05bad_row0_col1,#T_05bad_row1_col0,#T_05bad_row1_col1,#T_05bad_row2_col0,#T_05bad_row2_col1,#T_05bad_row3_col0,#T_05bad_row3_col1,#T_05bad_row4_col0,#T_05bad_row4_col1,#T_05bad_row5_col0,#T_05bad_row5_col1,#T_05bad_row6_col0,#T_05bad_row6_col1,#T_05bad_row7_col0,#T_05bad_row7_col1,#T_05bad_row8_col0,#T_05bad_row8_col1,#T_05bad_row9_col0,#T_05bad_row9_col1,#T_05bad_row10_col0,#T_05bad_row10_col1,#T_05bad_row11_col0,#T_05bad_row11_col1,#T_05bad_row12_col0,#T_05bad_row12_col1,#T_05bad_row13_col0,#T_05bad_row13_col1,#T_05bad_row14_col0,#T_05bad_row14_col1,#T_05bad_row15_col0,#T_05bad_row15_col1,#T_05bad_row16_col0,#T_05bad_row16_col1,#T_05bad_row17_col0,#T_05bad_row17_col1,#T_05bad_row18_col0,#T_05bad_row18_col1,#T_05bad_row19_col0,#T_05bad_row19_col1,#T_05bad_row20_col0,#T_05bad_row20_col1,#T_05bad_row21_col0,#T_05bad_row21_col1,#T_05bad_row22_col0,#T_05bad_row22_col1{
#             text-align:  center;
# ...

# %%
plot_distribution(df, 'Systolic blood pressure', 'Systolic blood pressure')

# %%
compare_feature_statistics('Systolic blood pressure')
# Out:
# <style  type="text/css" >
# #T_a5e94_row0_col0,#T_a5e94_row0_col1,#T_a5e94_row1_col0,#T_a5e94_row1_col1,#T_a5e94_row2_col0,#T_a5e94_row2_col1,#T_a5e94_row3_col0,#T_a5e94_row3_col1,#T_a5e94_row4_col0,#T_a5e94_row4_col1,#T_a5e94_row5_col0,#T_a5e94_row5_col1{
#             text-align:  center;
#         }</style><table id="T_a5e94_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5e94_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_a5e94_row0_col0" class="data row0 col0" >126</td>
#                         <td id="T_a5e94_row0_col1" class="data row0 col1" >127</td>
#             </tr>
#             <tr>
# ...

# %%
plot_MI_vs_Healthy("Systolic blood pressure", "Systolic blood pressure")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Diastolic blood pressure</h3>

# %%
explore_continuous_variable('Diastolic blood pressure')
# Out:
# <style  type="text/css" >
# #T_4eade_row0_col0,#T_4eade_row0_col1,#T_4eade_row1_col0,#T_4eade_row1_col1,#T_4eade_row2_col0,#T_4eade_row2_col1,#T_4eade_row3_col0,#T_4eade_row3_col1,#T_4eade_row4_col0,#T_4eade_row4_col1,#T_4eade_row5_col0,#T_4eade_row5_col1,#T_4eade_row6_col0,#T_4eade_row6_col1,#T_4eade_row7_col0,#T_4eade_row7_col1,#T_4eade_row8_col0,#T_4eade_row8_col1,#T_4eade_row9_col0,#T_4eade_row9_col1,#T_4eade_row10_col0,#T_4eade_row10_col1,#T_4eade_row11_col0,#T_4eade_row11_col1,#T_4eade_row12_col0,#T_4eade_row12_col1,#T_4eade_row13_col0,#T_4eade_row13_col1,#T_4eade_row14_col0,#T_4eade_row14_col1,#T_4eade_row15_col0,#T_4eade_row15_col1,#T_4eade_row16_col0,#T_4eade_row16_col1,#T_4eade_row17_col0,#T_4eade_row17_col1,#T_4eade_row18_col0,#T_4eade_row18_col1,#T_4eade_row19_col0,#T_4eade_row19_col1,#T_4eade_row20_col0,#T_4eade_row20_col1,#T_4eade_row21_col0,#T_4eade_row21_col1,#T_4eade_row22_col0,#T_4eade_row22_col1{
#             text-align:  center;
# ...

# %%
plot_distribution(df, 'Diastolic blood pressure', 'Diastolic blood pressure')

# %%
compare_feature_statistics('Diastolic blood pressure')
# Out:
# <style  type="text/css" >
# #T_e08a2_row0_col0,#T_e08a2_row0_col1,#T_e08a2_row1_col0,#T_e08a2_row1_col1,#T_e08a2_row2_col0,#T_e08a2_row2_col1,#T_e08a2_row3_col0,#T_e08a2_row3_col1,#T_e08a2_row4_col0,#T_e08a2_row4_col1,#T_e08a2_row5_col0,#T_e08a2_row5_col1{
#             text-align:  center;
#         }</style><table id="T_e08a2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e08a2_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_e08a2_row0_col0" class="data row0 col0" >72</td>
#                         <td id="T_e08a2_row0_col1" class="data row0 col1" >72</td>
#             </tr>
#             <tr>
# ...

# %%
plot_MI_vs_Healthy("Diastolic blood pressure", "Diastolic blood pressure")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Blood sugar</h3>

# %%
explore_continuous_variable('Blood sugar')
# Out:
# <style  type="text/css" >
# #T_34234_row0_col0,#T_34234_row0_col1,#T_34234_row1_col0,#T_34234_row1_col1,#T_34234_row2_col0,#T_34234_row2_col1,#T_34234_row3_col0,#T_34234_row3_col1,#T_34234_row4_col0,#T_34234_row4_col1,#T_34234_row5_col0,#T_34234_row5_col1,#T_34234_row6_col0,#T_34234_row6_col1,#T_34234_row7_col0,#T_34234_row7_col1,#T_34234_row8_col0,#T_34234_row8_col1,#T_34234_row9_col0,#T_34234_row9_col1,#T_34234_row10_col0,#T_34234_row10_col1,#T_34234_row11_col0,#T_34234_row11_col1,#T_34234_row12_col0,#T_34234_row12_col1,#T_34234_row13_col0,#T_34234_row13_col1,#T_34234_row14_col0,#T_34234_row14_col1,#T_34234_row15_col0,#T_34234_row15_col1,#T_34234_row16_col0,#T_34234_row16_col1,#T_34234_row17_col0,#T_34234_row17_col1,#T_34234_row18_col0,#T_34234_row18_col1,#T_34234_row19_col0,#T_34234_row19_col1,#T_34234_row20_col0,#T_34234_row20_col1,#T_34234_row21_col0,#T_34234_row21_col1,#T_34234_row22_col0,#T_34234_row22_col1{
#             text-align:  center;
# ...

# %%
plot_distribution(df, 'Blood sugar', 'Blood sugar')

# %%
compare_feature_statistics('Blood sugar')
# Out:
# <style  type="text/css" >
# #T_08be1_row0_col0,#T_08be1_row0_col1,#T_08be1_row1_col0,#T_08be1_row1_col1,#T_08be1_row2_col0,#T_08be1_row2_col1,#T_08be1_row3_col0,#T_08be1_row3_col1,#T_08be1_row4_col0,#T_08be1_row4_col1,#T_08be1_row5_col0,#T_08be1_row5_col1{
#             text-align:  center;
#         }</style><table id="T_08be1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08be1_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_08be1_row0_col0" class="data row0 col0" >144</td>
#                         <td id="T_08be1_row0_col1" class="data row0 col1" >149</td>
#             </tr>
#             <tr>
# ...

# %%
plot_MI_vs_Healthy("Blood sugar", "Blood sugar")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">CK-MB</h3>

# %%
explore_continuous_variable('CK-MB')
# Out:
# <style  type="text/css" >
# #T_0b60b_row0_col0,#T_0b60b_row0_col1,#T_0b60b_row1_col0,#T_0b60b_row1_col1,#T_0b60b_row2_col0,#T_0b60b_row2_col1,#T_0b60b_row3_col0,#T_0b60b_row3_col1,#T_0b60b_row4_col0,#T_0b60b_row4_col1,#T_0b60b_row5_col0,#T_0b60b_row5_col1,#T_0b60b_row6_col0,#T_0b60b_row6_col1,#T_0b60b_row7_col0,#T_0b60b_row7_col1,#T_0b60b_row8_col0,#T_0b60b_row8_col1,#T_0b60b_row9_col0,#T_0b60b_row9_col1,#T_0b60b_row10_col0,#T_0b60b_row10_col1,#T_0b60b_row11_col0,#T_0b60b_row11_col1,#T_0b60b_row12_col0,#T_0b60b_row12_col1,#T_0b60b_row13_col0,#T_0b60b_row13_col1,#T_0b60b_row14_col0,#T_0b60b_row14_col1,#T_0b60b_row15_col0,#T_0b60b_row15_col1,#T_0b60b_row16_col0,#T_0b60b_row16_col1,#T_0b60b_row17_col0,#T_0b60b_row17_col1,#T_0b60b_row18_col0,#T_0b60b_row18_col1,#T_0b60b_row19_col0,#T_0b60b_row19_col1,#T_0b60b_row20_col0,#T_0b60b_row20_col1,#T_0b60b_row21_col0,#T_0b60b_row21_col1,#T_0b60b_row22_col0,#T_0b60b_row22_col1{
#             text-align:  center;
# ...

# %%
plot_distribution(df, 'CK-MB', 'CK-MB')

# %%
compare_feature_statistics('CK-MB')
# Out:
# <style  type="text/css" >
# #T_19c2d_row0_col0,#T_19c2d_row0_col1,#T_19c2d_row1_col0,#T_19c2d_row1_col1,#T_19c2d_row2_col0,#T_19c2d_row2_col1,#T_19c2d_row3_col0,#T_19c2d_row3_col1,#T_19c2d_row4_col0,#T_19c2d_row4_col1,#T_19c2d_row5_col0,#T_19c2d_row5_col1{
#             text-align:  center;
#         }</style><table id="T_19c2d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19c2d_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_19c2d_row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_19c2d_row0_col1" class="data row0 col1" >2</td>
#             </tr>
#             <tr>
# ...

# %%
plot_MI_vs_Healthy("CK-MB", "CK-MB")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Troponin</h3>

# %%
explore_continuous_variable('Troponin')
# Out:
# <ipython-input-75-6fd738205731>:19: RuntimeWarning: divide by zero encountered in double_scalars
#   coefficient_of_variation = round(np.sqrt(variance) / mean, 2)
# <style  type="text/css" >
# ...

# %%
plot_distribution(df, 'Troponin', 'Troponin')

# %%
compare_feature_statistics('Troponin')
# Out:
# <style  type="text/css" >
# #T_7822b_row0_col0,#T_7822b_row0_col1,#T_7822b_row1_col0,#T_7822b_row1_col1,#T_7822b_row2_col0,#T_7822b_row2_col1,#T_7822b_row3_col0,#T_7822b_row3_col1,#T_7822b_row4_col0,#T_7822b_row4_col1,#T_7822b_row5_col0,#T_7822b_row5_col1{
#             text-align:  center;
#         }</style><table id="T_7822b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MI</th>        <th class="col_heading level0 col1" >Healthy</th>    </tr>    <tr>        <th class="index_name level0" >Statistics</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7822b_level0_row0" class="row_heading level0 row0" >Mean</th>
#                         <td id="T_7822b_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_7822b_row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
# ...

# %%
plot_MI_vs_Healthy("Troponin", "Troponin")

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Target</h3>

# %%
explore_categorical_variable('MI')
# Out:
#                Statistics  Values
# 0               Data Type  object
# 1                   Count    1319
# 2                    Mode      MI
# 3  Num of Possible values       2

# %%
pie_plot(df, 'MI', 'Target', colors=['#fe346e','#3081D0'])

# %%
explore_categories('MI',[1,0])
# Out:
#         MI  Count  Percentage
# 0       MI    810       61.41
# 1  Healthy    509       38.59

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Models Development</h3>

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Importing Libraries</h3>

# %%
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Data Scaling</h3>

# %%
categorical = [col for col in df.columns if df[col].dtype == "O"]
categorical
# Out:
# ['Gender']

# %%
numerical = [col for col in df.columns if df[col].dtype != "O"]
numerical = numerical[0:-1]
numerical
# Out:
# ['Age',
#  'Heart rate',
#  'Systolic blood pressure',
#  'Diastolic blood pressure',
#  'Blood sugar',
#  'CK-MB',
#  'Troponin']

# %%
X = df.drop('MI', axis=1)
Y = df['MI']

X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size=0.15, random_state=42, stratify=Y)

pipeline = ColumnTransformer([("scaler", StandardScaler() ,numerical ),
                               ("encoder", OneHotEncoder() , categorical)
                             ])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
joblib.dump(pipeline, "pipeline.joblib")
# Out:
# ['pipeline.joblib']

# %%
pipeline
# Out:
# ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                  ['Age', 'Heart rate',
#                                   'Systolic blood pressure',
#                                   'Diastolic blood pressure', 'Blood sugar',
#                                   'CK-MB', 'Troponin']),
#                                 ('encoder', OneHotEncoder(), ['Gender'])])

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:ghostwhite; font-family:newtimeroman; font-size:200%; text-align:center; display:inline-block; padding: 10px; border-radius: 15px;">Modeling</h3>

# %%
# function to automate modeling performance 
def evaluate_model(algorithm, X_train, Y_train, X_test, Y_test):
    # Train the model
    model = algorithm()
    model.fit(X_train, Y_train)

    # Make predictions
    predictions = model.predict(X_test)

    # Calculate performance metrics
    accuracy = round(accuracy_score(Y_test, predictions), 3)
    precision = round(precision_score(Y_test, predictions, pos_label= 1), 3)
    recall = round(recall_score(Y_test, predictions, pos_label= 1), 3)
    f1 = round(f1_score(Y_test, predictions, pos_label= 1), 3)

    # Create confusion matrix
    confusion_mat = confusion_matrix(Y_test, predictions)

    # Plot confusion matrix
    sns.heatmap(confusion_mat, annot=True, cmap='Blues', fmt='g')
    plt.title(f'Confusion Matrix - {algorithm.__name__}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # Print performance metrics
    print(f"{algorithm.__name__} Performance:")
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

    # Print classification report
    classification_rep = classification_report(Y_test, predictions)
    print("Classification Report:")
    print(classification_rep)

# %%
# Evaluate Logistic Regression
evaluate_model(LogisticRegression, X_train, Y_train, X_test, Y_test)
# Out:
# LogisticRegression Performance:
# Accuracy: 0.803
# Precision: 0.843
# Recall: 0.836
# F1 Score: 0.84
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.75        76
#            1       0.84      0.84      0.84       122
#
#     accuracy                           0.80       198
#    macro avg       0.79      0.79      0.79       198
# weighted avg       0.80      0.80      0.80       198

# %%
# Evaluate Decision Tree
evaluate_model(DecisionTreeClassifier, X_train, Y_train, X_test, Y_test)
# Out:
# DecisionTreeClassifier Performance:
# Accuracy: 0.98
# Precision: 0.984
# Recall: 0.984
# F1 Score: 0.984
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        76
#            1       0.98      0.98      0.98       122
#
#     accuracy                           0.98       198
#    macro avg       0.98      0.98      0.98       198
# weighted avg       0.98      0.98      0.98       198

# %%
# Evaluate Random Forest
evaluate_model(RandomForestClassifier, X_train, Y_train, X_test, Y_test)
# Out:
# RandomForestClassifier Performance:
# Accuracy: 0.98
# Precision: 0.984
# Recall: 0.984
# F1 Score: 0.984
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        76
#            1       0.98      0.98      0.98       122
#
#     accuracy                           0.98       198
#    macro avg       0.98      0.98      0.98       198
# weighted avg       0.98      0.98      0.98       198

# %%
# Evaluate Support Vector Machine (SVM)
evaluate_model(SVC, X_train, Y_train, X_test, Y_test)
# Out:
# SVC Performance:
# Accuracy: 0.753
# Precision: 0.807
# Recall: 0.787
# F1 Score: 0.797
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.70      0.68        76
#            1       0.81      0.79      0.80       122
#
#     accuracy                           0.75       198
#    macro avg       0.74      0.74      0.74       198
# weighted avg       0.75      0.75      0.75       198

# %%
# Evaluate Naive Bayes
evaluate_model(GaussianNB, X_train, Y_train, X_test, Y_test)
# Out:
# GaussianNB Performance:
# Accuracy: 0.692
# Precision: 0.984
# Recall: 0.508
# F1 Score: 0.67
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.99      0.71        76
#            1       0.98      0.51      0.67       122
#
#     accuracy                           0.69       198
#    macro avg       0.77      0.75      0.69       198
# weighted avg       0.82      0.69      0.69       198

# %%
# Evaluate K-Nearest Neighbors (KNN)
evaluate_model(KNeighborsClassifier, X_train, Y_train, X_test, Y_test)
# Out:
# KNeighborsClassifier Performance:
# Accuracy: 0.652
# Precision: 0.752
# Recall: 0.648
# F1 Score: 0.696
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.66      0.59        76
#            1       0.75      0.65      0.70       122
#
#     accuracy                           0.65       198
#    macro avg       0.65      0.65      0.64       198
# weighted avg       0.67      0.65      0.66       198

# %%
# Evaluate Gradient Boosting Classifier
evaluate_model(GradientBoostingClassifier, X_train, Y_train, X_test, Y_test)
# Out:
# GradientBoostingClassifier Performance:
# Accuracy: 0.98
# Precision: 0.984
# Recall: 0.984
# F1 Score: 0.984
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        76
#            1       0.98      0.98      0.98       122
#
#     accuracy                           0.98       198
#    macro avg       0.98      0.98      0.98       198
# weighted avg       0.98      0.98      0.98       198

# %%
rf =  RandomForestClassifier()
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# This results satisfies with the National Institute of Health and National Center for Biotechnology Information **(NCBI)** recommendations that  **"Although CK-MB has a high sensitivity for cardiac myocytes, it should not be used as a first-line diagnostic test if cardiac troponin assays are available. In the absence of cardiac troponin assays, CK-MB can be useful in the evaluation of acute MI, but it is far less sensitive and specific than cardiac troponins"**
#
# For more medical information and resources related to this
# https://www.ncbi.nlm.nih.gov/books/NBK545216/

# %%
joblib.dump(rf, 'model.joblib')
# Out:
# ['model.joblib']

# %%
del rf

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Data Correlation</h3>

# %%
df['Gender'] = df['Gender'].map({ 'male' : 1 , 'female' : 0 })

# %%
df.corr()
# Out:
#                                Age    Gender  Heart rate  \
# Age                       1.000000 -0.092874   -0.023440
# Gender                   -0.092874  1.000000   -0.026781
# Heart rate               -0.023440 -0.026781    1.000000
# Systolic blood pressure   0.017441  0.011065    0.010882
# Diastolic blood pressure  0.002614 -0.009370    0.108353
# Blood sugar              -0.004193  0.006668   -0.019584
# CK-MB                     0.018419  0.017527   -0.013001
# Troponin                  0.088800  0.065793    0.011180
# MI                        0.238097  0.094432    0.006920
#
#                           Systolic blood pressure  Diastolic blood pressure  \
# Age                                      0.017441                  0.002614
# Gender                                   0.011065                 -0.009370
# Heart rate                               0.010882                  0.108353
# Systolic blood pressure                  1.000000                  0.586166
# ...

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(), annot=True, annot_kws={"size": 15}, cmap='Blues')

plt.show()

# %% [markdown]
# # <a id="2.1"></a>
# <h3 style="background-color:lavender;font-family:newtimeroman;font-size:250%;text-align:center;border-radius: 15px 50px;">Deployment</h3>

# %%
input_data = {
 'Age': 60,
 'Gender': 'male',
 'Heart rate': 77,
 'Systolic blood pressure': 120,
 'Diastolic blood pressure': 50,
 'Blood sugar': 240,
 'CK-MB' : 14,
 'Troponin' : 0.12 
  }

# %%
del pipeline

# %%
pipeline = joblib.load("pipeline.joblib")

# %%
model = joblib.load("model.joblib")

# %%
def perform_prediction(input_data, pipeline, model):
    
    intput_df = pd.DataFrame(input_data, index=[0])
    
    preprocessed_data = pipeline.transform(intput_df)
    
    prediction = model.predict(preprocessed_data)
    
    return {"prediction":prediction[0]}

# %%
perform_prediction(input_data,pipeline,model)
# Out:
# {'prediction': 1}
